# %% [markdown]
# # **Extreme Classification by Optimizing Compositional Entropic Risk (SCENT)**

# %% [markdown]
# ## Prerequisites

# %%
# !gdown --folder 'https://drive.google.com/drive/folders/10cY2Azqz9Gnci-r4fXcGIpH_e5YaKXH_?usp=sharing' -O ./features

# %%
# !git clone https://github.com/xywei00/LibAUC.git -b xiyuan/1.5.0_dev

# %%
# !pip install ./LibAUC

# %%
import os
import logging
import pathlib
import json
import sys
import random
import math

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torch.optim.lr_scheduler import CosineAnnealingLR

from libauc.losses import EntLossClassification
from libauc.optimizers import SCENT

# %% [markdown]
# ## Helper Functions

# %%
class LinearClassifier(nn.Module):
    def __init__(self, feature_dim: int, num_classes: int):
        super().__init__()
        self.feature_dim = feature_dim
        self.num_classes = num_classes
        self.fc = nn.Linear(feature_dim, num_classes, bias=False)
        nn.init.normal_(self.fc.weight, mean=0.0, std=0.01)

    def forward(
        self,
        x: torch.Tensor,
        labels: torch.Tensor,
        classes: torch.Tensor | str | None = None,
        return_classes: bool = False,
    ):
        w_pos = self.fc.weight[labels]  # (B, D)

        mask = None
        sampled_classes = None
        if isinstance(classes, str):
            assert classes == "all"
            sampled_classes = torch.arange(self.num_classes, device=labels.device)
            w_sampled = self.fc.weight
        elif isinstance(classes, torch.Tensor):
            sampled_classes = classes.to(labels.device)
            w_sampled = self.fc.weight[sampled_classes]
        elif classes is None:
            sampled_classes = torch.unique(labels)
            w_sampled = self.fc.weight[sampled_classes]
            mask = labels.unsqueeze(1) == sampled_classes.unsqueeze(0)
        else:
            raise ValueError(f"Unknown classes type: {type(classes)}")

        logits = x @ w_sampled.T - torch.sum(x * w_pos, dim=1, keepdim=True)

        if mask is not None:
            logits = logits.masked_fill(mask.to(logits.device), float("-inf"))

        if return_classes:
            return logits, sampled_classes
        return logits

# %%
class FeaturesDataset(Dataset):
    """Dataset for precomputed features.

    Expects features_path (N, D) and labels_path (N,) where labels are ints 0..C-1.
    """

    def __init__(self, features_path: str, labels_path: str):
        self.features = torch.load(features_path, map_location="cpu")
        self.labels = torch.load(labels_path, map_location="cpu")
        assert self.features.shape[0] == self.labels.shape[0], "features/labels length mismatch"

    def __len__(self):
        return self.features.shape[0]

    def __getitem__(self, idx):
        x = self.features[idx]
        y = self.labels[idx]
        return x, y, idx

# %%
def setup_logging(out_log_file=None):
    logging.root.handlers = []
    logging.root.setLevel(level=logging.INFO)

    formatter = logging.Formatter(
        "%(asctime)s | %(levelname)s | %(message)s", datefmt="%Y-%m-%d,%H:%M:%S"
    )

    stream_handler = logging.StreamHandler()
    stream_handler.setFormatter(formatter)
    logging.root.addHandler(stream_handler)

    if out_log_file is not None:
        file_handler = logging.FileHandler(out_log_file)
        file_handler.setFormatter(formatter)
        logging.root.addHandler(file_handler)


def build_dataloaders(root_data_dir, batch_size, num_workers=0):
    dataloader_list = []
    for split, shuffle in zip(["train", "val", "test"], [True, False, False]):
        data_dir = os.path.join(root_data_dir, split)
        if not os.path.exists(data_dir):
            if split in ["train", "val"]:
                raise FileNotFoundError(f"Data directory {data_dir} does not exist.")
            dataloader_list.append(None)
            continue

        features = os.path.join(data_dir, "features.pt")
        labels = os.path.join(data_dir, "labels.pt")
        ds = FeaturesDataset(features, labels)
        dataloader = DataLoader(
            ds,
            batch_size=batch_size,
            shuffle=shuffle,
            num_workers=num_workers,
        )
        dataloader_list.append(dataloader)

    train_loader, val_loader, test_loader = dataloader_list
    return train_loader, val_loader, test_loader


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    logging.info(f"Set random seed to {seed}")


def compute_log_priors(train_loader, num_classes):
    counts = torch.zeros(num_classes, dtype=torch.float32)
    for _, labels, _ in train_loader:
        counts += torch.bincount(labels, minlength=num_classes).float()
    priors = counts / counts.sum()
    priors = priors.clamp_min(1e-12)
    return priors.log()


def apply_la_to_sampled_logits(logits, sampled_classes, labels, log_priors, tau):
    if tau <= 0:
        return logits
    neg_shift = log_priors[sampled_classes].unsqueeze(0)
    pos_shift = log_priors[labels].unsqueeze(1)
    return logits + tau * (neg_shift - pos_shift)


def evaluate(model, loader, device, log_priors=None, eval_tau=0.0):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for i, batch in enumerate(loader):
            feats, labels, _ = batch
            feats = feats.to(device)
            labels = labels.to(device, dtype=torch.long)

            logits = model.fc(feats)

            if log_priors is not None and eval_tau > 0:
                logits = logits + eval_tau * log_priors.to(device).unsqueeze(0)

            loss = F.cross_entropy(logits, labels)
            total_loss += loss.item() * feats.size(0)
            preds = logits.argmax(dim=1)
            correct += (preds == labels).sum().item()
            total += feats.size(0)

            if i % 200 == 0:
                logging.info(f"  Batch {i} / {len(loader)}: loss={loss.item():.6f}")

    return total_loss / total, correct / total


def train_one_epoch(
    model,
    loader,
    optimizer,
    criterion,
    device,
    log_priors=None,
    train_tau=0.0,
    use_tis=False,
    tis_topk=32,
    tis_temp=0.5,
    tis_eps=1e-8,
):
    model.train()
    total_loss = 0.0
    total = 0

    for i, batch in enumerate(loader):
        feats, labels, indices = batch
        feats = feats.to(device, non_blocking=True)
        labels = labels.to(device, dtype=torch.long, non_blocking=True)

        logits, sampled_classes = model(feats, labels, return_classes=True)
        logits = apply_la_to_sampled_logits(logits, sampled_classes, labels, log_priors, train_tau)

        if use_tis:
            logits = apply_tis_proxy_to_sampled_logits(
                logits,
                topk=tis_topk,
                temperature=tis_temp,
                eps=tis_eps,
            )
        loss_dict = criterion(logits, indices)
        loss = loss_dict["loss"]

        with torch.no_grad():
            model.eval()
            base_logits = model.fc(feats)
            cross_entropy_loss = F.cross_entropy(base_logits, labels)
            loss_dict["cross_entropy_loss"] = cross_entropy_loss
            model.train()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += cross_entropy_loss.item() * feats.size(0)
        total += feats.size(0)

        if i % 200 == 0:
            log_str = f"  Batch {i} / {len(loader)}:"
            for key, value in loss_dict.items():
                log_str += f" {key}={value.item():.6f}"
            logging.info(log_str)

    return total_loss / total


def make_scheduler(optimizer, epochs, warmup_epochs=0):
    def lr_lambda(epoch_idx):
        epoch_num = epoch_idx + 1
        if warmup_epochs > 0 and epoch_num <= warmup_epochs:
            return epoch_num / warmup_epochs

        if epochs == warmup_epochs:
            return 1.0

        progress = (epoch_num - warmup_epochs) / max(1, epochs - warmup_epochs)
        progress = min(max(progress, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))

    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lr_lambda)


def apply_tis_proxy_to_sampled_logits(
    logits,
    topk=32,
    temperature=0.5,
    eps=1e-8,
):
    """
    GPU-friendly hard-negative importance sampler over the already-sampled
    batch candidate classes.

    This is a taxonomy-inspired proxy:
    - proposal Q is built from batch hardness scores on GPU
    - a subset of negative columns is sampled
    - logits are importance-corrected by log rho
    """
    valid_mask = torch.isfinite(logits)  # shape [B, K]
    B, K = logits.shape

    if K <= topk:
        return logits

    # hardness score for each sampled class column
    masked_logits = torch.where(valid_mask, logits.detach(), torch.full_like(logits, -1e9))
    class_scores = masked_logits.amax(dim=0)  # shape [K]

    # proposal Q over sampled classes
    proposal = torch.softmax(class_scores / temperature, dim=0)
    proposal = proposal.clamp_min(eps)

    m = min(topk, K)
    keep_idx = torch.multinomial(proposal, num_samples=m, replacement=False)
    keep_idx, _ = torch.sort(keep_idx)

    logits_sub = logits[:, keep_idx]
    q_keep = proposal[keep_idx].unsqueeze(0)  # [1, m]

    # uniform target over the current sampled class set
    rho = (1.0 / K) / q_keep
    logits_sub = logits_sub + torch.log(rho)

    return logits_sub

# %%
data_dir = "./features/treeoflife10m_subset"
root_out_dir = "./outputs_exp4_tis/"

seed = 2026
device = "cuda"
feature_dim = 512
num_classes = 163002
data_size = 762654
save_frequency = 1

epochs = 20
batch_size = 128

setup_logging()

# %%
EXPERIMENTS = [
    dict(
        name="exp4_cfg01_scent_ref",
        algorithm="scent",
        lr=0.002,
        alpha=0.0,
        alpha_multiplier=0.03,
        momentum=0.9,
        weight_decay=0.0,
        train_tau=0.0,
        eval_tau=0.0,
        warmup_epochs=0,
        use_tis=False,
        tis_topk=32,
        tis_temp=0.5,
        tis_eps=1e-8,
    ),
    dict(
        name="exp4_cfg02_scent_warmup_ref",
        algorithm="scent",
        lr=0.002,
        alpha=0.0,
        alpha_multiplier=0.03,
        momentum=0.9,
        weight_decay=0.0,
        train_tau=0.0,
        eval_tau=0.0,
        warmup_epochs=2,
        use_tis=False,
        tis_topk=32,
        tis_temp=0.5,
        tis_eps=1e-8,
    ),
    dict(
        name="exp4_cfg03_scent_tis_proxy",
        algorithm="scent",
        lr=0.002,
        alpha=0.0,
        alpha_multiplier=0.03,
        momentum=0.9,
        weight_decay=0.0,
        train_tau=0.0,
        eval_tau=0.0,
        warmup_epochs=0,
        use_tis=True,
        tis_topk=32,
        tis_temp=0.5,
        tis_eps=1e-8,
    ),
    dict(
        name="exp4_cfg06_scent_tis_k96_t1p5",
        algorithm="scent",
        lr=0.002,
        alpha=0.0,
        alpha_multiplier=0.03,
        momentum=0.9,
        weight_decay=0.0,
        train_tau=0.0,
        eval_tau=0.0,
        warmup_epochs=0,
        use_tis=True,
        tis_topk=96,
        tis_temp=1.5,
        tis_eps=1e-8,
    ),
    dict(
        name="exp4_cfg07_scent_warmup_tis_k64_t1p0",
        algorithm="scent",
        lr=0.002,
        alpha=0.0,
        alpha_multiplier=0.03,
        momentum=0.9,
        weight_decay=0.0,
        train_tau=0.0,
        eval_tau=0.0,
        warmup_epochs=2,
        use_tis=True,
        tis_topk=64,
        tis_temp=1.0,
        tis_eps=1e-8,
    ),
]

# %% [markdown]
# ## Training

# %%
def build_experiment(cfg):
    name = cfg["name"]
    out_dir = pathlib.Path(root_out_dir) / name
    os.makedirs(out_dir / "checkpoints", exist_ok=True)
    out_log_file = out_dir / "out.log"

    setup_logging(out_log_file)
    set_seed(seed)

    train_loader, val_loader, test_loader = build_dataloaders(data_dir, batch_size, num_workers=0)
    model = LinearClassifier(feature_dim, num_classes).to(device)

    optimizer = SCENT(
        model.parameters(),
        lr=cfg["lr"],
        momentum=cfg["momentum"],
        weight_decay=cfg["weight_decay"],
    )

    lr_scheduler = make_scheduler(
        optimizer,
        epochs=epochs,
        warmup_epochs=cfg["warmup_epochs"],
    )

    if cfg["algorithm"] == "scent":
        criterion = EntLossClassification(
            data_size=data_size,
            alpha=cfg["alpha"],
            is_scent=True,
            alpha_multiplier=cfg["alpha_multiplier"],
        )
    elif cfg["algorithm"] == "sox":
        criterion = EntLossClassification(
            data_size=data_size,
            gamma=cfg["gamma"],
            is_scent=False,
        )
    else:
        raise ValueError(cfg["algorithm"])

    log_priors = compute_log_priors(train_loader, num_classes).to(device)

    return {
        "name": name,
        "out_dir": out_dir,
        "train_loader": train_loader,
        "val_loader": val_loader,
        "test_loader": test_loader,
        "model": model,
        "optimizer": optimizer,
        "lr_scheduler": lr_scheduler,
        "criterion": criterion,
        "log_priors": log_priors,
    }


def run_experiment(cfg):
    exp = build_experiment(cfg)

    name = exp["name"]
    out_dir = exp["out_dir"]
    train_loader = exp["train_loader"]
    val_loader = exp["val_loader"]
    test_loader = exp["test_loader"]
    model = exp["model"]
    optimizer = exp["optimizer"]
    lr_scheduler = exp["lr_scheduler"]
    criterion = exp["criterion"]
    log_priors = exp["log_priors"]

    best_val_acc = 0.0
    best_test_acc = 0.0
    best_test_loss = float("inf")
    all_rows = []

    for epoch in range(1, epochs + 1):
        logging.info(
            f"{name} | Epoch {epoch}/{epochs}, learning_rate={lr_scheduler.get_last_lr()[0]:.6f}"
        )

        if hasattr(criterion, "adjust_gamma"):
            criterion.adjust_gamma(epoch, epochs)

        train_ce = train_one_epoch(
            model,
            train_loader,
            optimizer,
            criterion,
            device,
            log_priors=log_priors,
            train_tau=cfg["train_tau"],
            use_tis=cfg["use_tis"],
            tis_topk=cfg["tis_topk"],
            tis_temp=cfg["tis_temp"],
            tis_eps=cfg["tis_eps"],
        )

        lr_scheduler.step()

        logging.info("Evaluating on validation set")
        val_loss, val_acc = evaluate(
            model,
            val_loader,
            device,
            log_priors=log_priors,
            eval_tau=cfg["eval_tau"],
        )

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            if test_loader is not None:
                logging.info("Evaluating on test set")
                best_test_loss, best_test_acc = evaluate(
                    model,
                    test_loader,
                    device,
                    log_priors=log_priors,
                    eval_tau=cfg["eval_tau"],
                )

        row = {
            "epoch": epoch,
            "cross_entropy_loss": train_ce,
            "val_loss": val_loss,
            "val_acc": val_acc,
            "best_val_acc": best_val_acc,
            "best_test_acc": best_test_acc,
            "best_test_loss": best_test_loss,
        }
        all_rows.append(row)

        logging.info(
            f"{name} | epoch={epoch} train_ce={train_ce:.6f} "
            f"val_loss={val_loss:.6f} val_acc={val_acc:.6f} "
            f"best_val_acc={best_val_acc:.6f} "
            f"best_test_acc={best_test_acc:.6f}"
        )

        with open(out_dir / f"eval_{name}.jsonl", "w") as f:
            f.write(json.dumps(row) + "\n")

        if epoch % save_frequency == 0 or epoch == epochs:
            save_dict = {
                "model_state": model.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "epoch": epoch,
                "config": cfg,
            }
            if hasattr(criterion, "nu"):
                save_dict["criterion_nu"] = criterion.nu.cpu()
            torch.save(save_dict, out_dir / "checkpoints" / f"epoch_{epoch}.pt")

    return all_rows

# %%
for i in range(5):
    run_experiment(EXPERIMENTS[i])
# Out:
# 2026-04-21,03:42:58 | INFO | Set random seed to 2026
# 2026-04-21,03:43:02 | INFO | exp4_cfg01_scent_ref | Epoch 1/20, learning_rate=0.001988
# 2026-04-21,03:43:02 | INFO |   Batch 0 / 5959: loss=1.000000 cross_entropy_loss=12.003008
# 2026-04-21,03:43:04 | INFO |   Batch 200 / 5959: loss=1.000000 cross_entropy_loss=11.985254
# 2026-04-21,03:43:06 | INFO |   Batch 400 / 5959: loss=1.000000 cross_entropy_loss=11.963149
# 2026-04-21,03:43:08 | INFO |   Batch 600 / 5959: loss=1.000000 cross_entropy_loss=11.912365
# 2026-04-21,03:43:09 | INFO |   Batch 800 / 5959: loss=1.000000 cross_entropy_loss=11.908283
# 2026-04-21,03:43:11 | INFO |   Batch 1000 / 5959: loss=1.000000 cross_entropy_loss=11.797287
# 2026-04-21,03:43:13 | INFO |   Batch 1200 / 5959: loss=1.000000 cross_entropy_loss=11.794004
# 2026-04-21,03:43:14 | INFO |   Batch 1400 / 5959: loss=1.000000 cross_entropy_loss=11.820024
# 2026-04-21,03:43:16 | INFO |   Batch 1600 / 5959: loss=1.000000 cross_entropy_loss=11.619745
# 2026-04-21,03:43:17 | INFO |   Batch 1800 / 5959: loss=1.000000 cross_entropy_loss=11.673975
# 2026-04-21,03:43:19 | INFO |   Batch 2000 / 5959: loss=1.000000 cross_entropy_loss=11.640581
# 2026-04-21,03:43:21 | INFO |   Batch 2200 / 5959: loss=1.000000 cross_entropy_loss=11.666014
# 2026-04-21,03:43:22 | INFO |   Batch 2400 / 5959: loss=1.000000 cross_entropy_loss=11.713610
# 2026-04-21,03:43:24 | INFO |   Batch 2600 / 5959: loss=1.000000 cross_entropy_loss=11.408641
# 2026-04-21,03:43:26 | INFO |   Batch 2800 / 5959: loss=1.000000 cross_entropy_loss=11.582956
# 2026-04-21,03:43:27 | INFO |   Batch 3000 / 5959: loss=1.000000 cross_entropy_loss=11.669733
# 2026-04-21,03:43:29 | INFO |   Batch 3200 / 5959: loss=1.000000 cross_entropy_loss=11.588900
# 2026-04-21,03:43:30 | INFO |   Batch 3400 / 5959: loss=1.000000 cross_entropy_loss=11.477024
# 2026-04-21,03:43:32 | INFO |   Batch 3600 / 5959: loss=1.000000 cross_entropy_loss=11.444149
# 2026-04-21,03:43:34 | INFO |   Batch 3800 / 5959: loss=1.000000 cross_entropy_loss=11.283691
# 2026-04-21,03:43:35 | INFO |   Batch 4000 / 5959: loss=1.000000 cross_entropy_loss=11.529682
# 2026-04-21,03:43:37 | INFO |   Batch 4200 / 5959: loss=1.000000 cross_entropy_loss=11.235439
# 2026-04-21,03:43:39 | INFO |   Batch 4400 / 5959: loss=1.000000 cross_entropy_loss=11.378469
# 2026-04-21,03:43:40 | INFO |   Batch 4600 / 5959: loss=1.000000 cross_entropy_loss=11.291690
# 2026-04-21,03:43:42 | INFO |   Batch 4800 / 5959: loss=1.000000 cross_entropy_loss=11.275511
# 2026-04-21,03:43:43 | INFO |   Batch 5000 / 5959: loss=1.000000 cross_entropy_loss=11.558066
# 2026-04-21,03:43:45 | INFO |   Batch 5200 / 5959: loss=1.000000 cross_entropy_loss=11.428759
# 2026-04-21,03:43:47 | INFO |   Batch 5400 / 5959: loss=1.000000 cross_entropy_loss=10.888706
# 2026-04-21,03:43:48 | INFO |   Batch 5600 / 5959: loss=1.000000 cross_entropy_loss=11.206848
# 2026-04-21,03:43:50 | INFO |   Batch 5800 / 5959: loss=1.000000 cross_entropy_loss=10.695316
# 2026-04-21,03:43:51 | INFO | Evaluating on validation set
# 2026-04-21,03:43:51 | INFO |   Batch 0 / 745: loss=11.093120
# 2026-04-21,03:43:52 | INFO |   Batch 200 / 745: loss=11.036639
# 2026-04-21,03:43:52 | INFO |   Batch 400 / 745: loss=11.222281
# 2026-04-21,03:43:52 | INFO |   Batch 600 / 745: loss=10.942076
# 2026-04-21,03:43:53 | INFO | exp4_cfg01_scent_ref | epoch=1 train_ce=11.522433 val_loss=11.084069 val_acc=0.134479 best_val_acc=0.134479 best_test_acc=0.000000
# 2026-04-21,03:43:53 | INFO | exp4_cfg01_scent_ref | Epoch 2/20, learning_rate=0.001951
# 2026-04-21,03:43:53 | INFO |   Batch 0 / 5959: loss=0.928432 cross_entropy_loss=11.446117
# 2026-04-21,03:43:55 | INFO |   Batch 200 / 5959: loss=0.934862 cross_entropy_loss=11.426891
# 2026-04-21,03:43:57 | INFO |   Batch 400 / 5959: loss=0.855213 cross_entropy_loss=10.892336
# 2026-04-21,03:43:58 | INFO |   Batch 600 / 5959: loss=0.854428 cross_entropy_loss=10.612587
# 2026-04-21,03:44:00 | INFO |   Batch 800 / 5959: loss=0.890662 cross_entropy_loss=11.017406
# 2026-04-21,03:44:01 | INFO |   Batch 1000 / 5959: loss=0.870829 cross_entropy_loss=10.993913
# 2026-04-21,03:44:03 | INFO |   Batch 1200 / 5959: loss=0.876277 cross_entropy_loss=11.044921
# 2026-04-21,03:44:05 | INFO |   Batch 1400 / 5959: loss=0.901819 cross_entropy_loss=11.170265
# 2026-04-21,03:44:06 | INFO |   Batch 1600 / 5959: loss=0.863312 cross_entropy_loss=11.050827
# 2026-04-21,03:44:08 | INFO |   Batch 1800 / 5959: loss=0.854632 cross_entropy_loss=11.030202
# 2026-04-21,03:44:10 | INFO |   Batch 2000 / 5959: loss=0.843219 cross_entropy_loss=10.819870
# 2026-04-21,03:44:11 | INFO |   Batch 2200 / 5959: loss=0.845419 cross_entropy_loss=10.754795
# 2026-04-21,03:44:13 | INFO |   Batch 2400 / 5959: loss=0.815197 cross_entropy_loss=10.525747
# 2026-04-21,03:44:14 | INFO |   Batch 2600 / 5959: loss=0.883183 cross_entropy_loss=10.968642
# 2026-04-21,03:44:16 | INFO |   Batch 2800 / 5959: loss=0.854367 cross_entropy_loss=10.947725
# 2026-04-21,03:44:18 | INFO |   Batch 3000 / 5959: loss=0.827013 cross_entropy_loss=10.780297
# 2026-04-21,03:44:19 | INFO |   Batch 3200 / 5959: loss=0.851765 cross_entropy_loss=11.013711
# 2026-04-21,03:44:21 | INFO |   Batch 3400 / 5959: loss=0.819696 cross_entropy_loss=10.858203
# 2026-04-21,03:44:22 | INFO |   Batch 3600 / 5959: loss=0.872182 cross_entropy_loss=11.152098
# 2026-04-21,03:44:24 | INFO |   Batch 3800 / 5959: loss=0.852965 cross_entropy_loss=11.058105
# 2026-04-21,03:44:26 | INFO |   Batch 4000 / 5959: loss=0.880901 cross_entropy_loss=11.245975
# 2026-04-21,03:44:27 | INFO |   Batch 4200 / 5959: loss=0.848830 cross_entropy_loss=11.005495
# 2026-04-21,03:44:29 | INFO |   Batch 4400 / 5959: loss=0.825409 cross_entropy_loss=10.825538
# 2026-04-21,03:44:31 | INFO |   Batch 4600 / 5959: loss=0.837907 cross_entropy_loss=10.870245
# 2026-04-21,03:44:32 | INFO |   Batch 4800 / 5959: loss=0.864782 cross_entropy_loss=11.171751
# 2026-04-21,03:44:34 | INFO |   Batch 5000 / 5959: loss=0.816663 cross_entropy_loss=10.904262
# 2026-04-21,03:44:35 | INFO |   Batch 5200 / 5959: loss=0.828653 cross_entropy_loss=10.900231
# 2026-04-21,03:44:37 | INFO |   Batch 5400 / 5959: loss=0.836847 cross_entropy_loss=11.090857
# 2026-04-21,03:44:39 | INFO |   Batch 5600 / 5959: loss=0.796551 cross_entropy_loss=10.657785
# 2026-04-21,03:44:40 | INFO |   Batch 5800 / 5959: loss=0.836484 cross_entropy_loss=10.985216
# 2026-04-21,03:44:42 | INFO | Evaluating on validation set
# 2026-04-21,03:44:42 | INFO |   Batch 0 / 745: loss=10.960319
# 2026-04-21,03:44:42 | INFO |   Batch 200 / 745: loss=10.877915
# 2026-04-21,03:44:42 | INFO |   Batch 400 / 745: loss=11.085617
# 2026-04-21,03:44:43 | INFO |   Batch 600 / 745: loss=10.790091
# 2026-04-21,03:44:43 | INFO | exp4_cfg01_scent_ref | epoch=2 train_ce=11.000266 val_loss=10.944820 val_acc=0.144308 best_val_acc=0.144308 best_test_acc=0.000000
# 2026-04-21,03:44:44 | INFO | exp4_cfg01_scent_ref | Epoch 3/20, learning_rate=0.001891
# 2026-04-21,03:44:44 | INFO |   Batch 0 / 5959: loss=0.865850 cross_entropy_loss=11.014993
# 2026-04-21,03:44:45 | INFO |   Batch 200 / 5959: loss=0.831848 cross_entropy_loss=10.788543
# 2026-04-21,03:44:47 | INFO |   Batch 400 / 5959: loss=0.812086 cross_entropy_loss=10.564133
# 2026-04-21,03:44:48 | INFO |   Batch 600 / 5959: loss=0.844752 cross_entropy_loss=10.859869
# 2026-04-21,03:44:50 | INFO |   Batch 800 / 5959: loss=0.824089 cross_entropy_loss=10.657425
# 2026-04-21,03:44:52 | INFO |   Batch 1000 / 5959: loss=0.837746 cross_entropy_loss=10.854374
# 2026-04-21,03:44:53 | INFO |   Batch 1200 / 5959: loss=0.821695 cross_entropy_loss=10.723135
# 2026-04-21,03:44:55 | INFO |   Batch 1400 / 5959: loss=0.856159 cross_entropy_loss=10.933915
# 2026-04-21,03:44:56 | INFO |   Batch 1600 / 5959: loss=0.867094 cross_entropy_loss=11.248829
# 2026-04-21,03:44:58 | INFO |   Batch 1800 / 5959: loss=0.859823 cross_entropy_loss=11.068398
# 2026-04-21,03:45:00 | INFO |   Batch 2000 / 5959: loss=0.807630 cross_entropy_loss=10.681920
# 2026-04-21,03:45:01 | INFO |   Batch 2200 / 5959: loss=0.813381 cross_entropy_loss=10.730427
# 2026-04-21,03:45:03 | INFO |   Batch 2400 / 5959: loss=0.772021 cross_entropy_loss=10.418358
# 2026-04-21,03:45:05 | INFO |   Batch 2600 / 5959: loss=0.817949 cross_entropy_loss=10.612781
# 2026-04-21,03:45:06 | INFO |   Batch 2800 / 5959: loss=0.813719 cross_entropy_loss=10.843499
# 2026-04-21,03:45:08 | INFO |   Batch 3000 / 5959: loss=0.784052 cross_entropy_loss=10.407204
# 2026-04-21,03:45:09 | INFO |   Batch 3200 / 5959: loss=0.810957 cross_entropy_loss=10.809624
# 2026-04-21,03:45:11 | INFO |   Batch 3400 / 5959: loss=0.842895 cross_entropy_loss=10.850654
# 2026-04-21,03:45:13 | INFO |   Batch 3600 / 5959: loss=0.835836 cross_entropy_loss=11.121446
# 2026-04-21,03:45:14 | INFO |   Batch 3800 / 5959: loss=0.819200 cross_entropy_loss=10.815714
# 2026-04-21,03:45:16 | INFO |   Batch 4000 / 5959: loss=0.820312 cross_entropy_loss=10.872623
# 2026-04-21,03:45:18 | INFO |   Batch 4200 / 5959: loss=0.793758 cross_entropy_loss=10.705244
# 2026-04-21,03:45:19 | INFO |   Batch 4400 / 5959: loss=0.798982 cross_entropy_loss=10.868624
# 2026-04-21,03:45:21 | INFO |   Batch 4600 / 5959: loss=0.777392 cross_entropy_loss=10.502566
# 2026-04-21,03:45:22 | INFO |   Batch 4800 / 5959: loss=0.814212 cross_entropy_loss=10.838761
# 2026-04-21,03:45:24 | INFO |   Batch 5000 / 5959: loss=0.808463 cross_entropy_loss=10.804344
# 2026-04-21,03:45:26 | INFO |   Batch 5200 / 5959: loss=0.783995 cross_entropy_loss=10.682647
# 2026-04-21,03:45:27 | INFO |   Batch 5400 / 5959: loss=0.784990 cross_entropy_loss=10.385597
# 2026-04-21,03:45:29 | INFO |   Batch 5600 / 5959: loss=0.773902 cross_entropy_loss=10.627894
# 2026-04-21,03:45:30 | INFO |   Batch 5800 / 5959: loss=0.790226 cross_entropy_loss=10.635504
# 2026-04-21,03:45:32 | INFO | Evaluating on validation set
# 2026-04-21,03:45:32 | INFO |   Batch 0 / 745: loss=10.792828
# 2026-04-21,03:45:32 | INFO |   Batch 200 / 745: loss=10.695387
# 2026-04-21,03:45:33 | INFO |   Batch 400 / 745: loss=10.925158
# 2026-04-21,03:45:33 | INFO |   Batch 600 / 745: loss=10.603409
# 2026-04-21,03:45:33 | INFO | exp4_cfg01_scent_ref | epoch=3 train_ce=10.806383 val_loss=10.774944 val_acc=0.161291 best_val_acc=0.161291 best_test_acc=0.000000
# 2026-04-21,03:45:34 | INFO | exp4_cfg01_scent_ref | Epoch 4/20, learning_rate=0.001809
# 2026-04-21,03:45:34 | INFO |   Batch 0 / 5959: loss=0.830278 cross_entropy_loss=10.766487
# 2026-04-21,03:45:35 | INFO |   Batch 200 / 5959: loss=0.805304 cross_entropy_loss=10.691017
# 2026-04-21,03:45:37 | INFO |   Batch 400 / 5959: loss=0.858566 cross_entropy_loss=11.102175
# 2026-04-21,03:45:39 | INFO |   Batch 600 / 5959: loss=0.836683 cross_entropy_loss=10.835951
# 2026-04-21,03:45:40 | INFO |   Batch 800 / 5959: loss=0.778247 cross_entropy_loss=10.085526
# 2026-04-21,03:45:42 | INFO |   Batch 1000 / 5959: loss=0.808813 cross_entropy_loss=10.629562
# 2026-04-21,03:45:43 | INFO |   Batch 1200 / 5959: loss=0.794197 cross_entropy_loss=10.539217
# 2026-04-21,03:45:45 | INFO |   Batch 1400 / 5959: loss=0.815885 cross_entropy_loss=10.699853
# 2026-04-21,03:45:47 | INFO |   Batch 1600 / 5959: loss=0.813040 cross_entropy_loss=10.685358
# 2026-04-21,03:45:48 | INFO |   Batch 1800 / 5959: loss=0.808591 cross_entropy_loss=10.608150
# 2026-04-21,03:45:50 | INFO |   Batch 2000 / 5959: loss=0.797753 cross_entropy_loss=10.453411
# 2026-04-21,03:45:52 | INFO |   Batch 2200 / 5959: loss=0.767802 cross_entropy_loss=10.183447
# 2026-04-21,03:45:53 | INFO |   Batch 2400 / 5959: loss=0.827020 cross_entropy_loss=10.912219
# 2026-04-21,03:45:55 | INFO |   Batch 2600 / 5959: loss=0.791564 cross_entropy_loss=10.684690
# 2026-04-21,03:45:56 | INFO |   Batch 2800 / 5959: loss=0.766555 cross_entropy_loss=10.302469
# 2026-04-21,03:45:58 | INFO |   Batch 3000 / 5959: loss=0.756996 cross_entropy_loss=10.235201
# 2026-04-21,03:46:00 | INFO |   Batch 3200 / 5959: loss=0.786609 cross_entropy_loss=10.361252
# 2026-04-21,03:46:01 | INFO |   Batch 3400 / 5959: loss=0.801947 cross_entropy_loss=10.654323
# 2026-04-21,03:46:03 | INFO |   Batch 3600 / 5959: loss=0.736729 cross_entropy_loss=9.920748
# 2026-04-21,03:46:04 | INFO |   Batch 3800 / 5959: loss=0.793721 cross_entropy_loss=10.710749
# 2026-04-21,03:46:06 | INFO |   Batch 4000 / 5959: loss=0.811215 cross_entropy_loss=10.686731
# 2026-04-21,03:46:08 | INFO |   Batch 4200 / 5959: loss=0.793585 cross_entropy_loss=10.515926
# 2026-04-21,03:46:09 | INFO |   Batch 4400 / 5959: loss=0.764051 cross_entropy_loss=10.311050
# 2026-04-21,03:46:11 | INFO |   Batch 4600 / 5959: loss=0.773056 cross_entropy_loss=10.520990
# 2026-04-21,03:46:13 | INFO |   Batch 4800 / 5959: loss=0.801831 cross_entropy_loss=10.679068
# 2026-04-21,03:46:14 | INFO |   Batch 5000 / 5959: loss=0.756539 cross_entropy_loss=10.348964
# 2026-04-21,03:46:16 | INFO |   Batch 5200 / 5959: loss=0.783431 cross_entropy_loss=10.790901
# 2026-04-21,03:46:17 | INFO |   Batch 5400 / 5959: loss=0.766798 cross_entropy_loss=10.432844
# 2026-04-21,03:46:19 | INFO |   Batch 5600 / 5959: loss=0.781822 cross_entropy_loss=10.807836
# 2026-04-21,03:46:21 | INFO |   Batch 5800 / 5959: loss=0.789115 cross_entropy_loss=10.878327
# 2026-04-21,03:46:22 | INFO | Evaluating on validation set
# 2026-04-21,03:46:22 | INFO |   Batch 0 / 745: loss=10.637636
# 2026-04-21,03:46:22 | INFO |   Batch 200 / 745: loss=10.531605
# 2026-04-21,03:46:23 | INFO |   Batch 400 / 745: loss=10.775364
# 2026-04-21,03:46:23 | INFO |   Batch 600 / 745: loss=10.433336
# 2026-04-21,03:46:23 | INFO | exp4_cfg01_scent_ref | epoch=4 train_ce=10.614701 val_loss=10.619423 val_acc=0.182847 best_val_acc=0.182847 best_test_acc=0.000000
# 2026-04-21,03:46:24 | INFO | exp4_cfg01_scent_ref | Epoch 5/20, learning_rate=0.001707
# 2026-04-21,03:46:24 | INFO |   Batch 0 / 5959: loss=0.803883 cross_entropy_loss=10.314436
# 2026-04-21,03:46:26 | INFO |   Batch 200 / 5959: loss=0.823362 cross_entropy_loss=10.531340
# 2026-04-21,03:46:27 | INFO |   Batch 400 / 5959: loss=0.847183 cross_entropy_loss=10.645882
# 2026-04-21,03:46:29 | INFO |   Batch 600 / 5959: loss=0.804419 cross_entropy_loss=10.361543
# 2026-04-21,03:46:30 | INFO |   Batch 800 / 5959: loss=0.785886 cross_entropy_loss=10.086519
# 2026-04-21,03:46:32 | INFO |   Batch 1000 / 5959: loss=0.855659 cross_entropy_loss=10.872080
# 2026-04-21,03:46:34 | INFO |   Batch 1200 / 5959: loss=0.808899 cross_entropy_loss=10.361710
# 2026-04-21,03:46:35 | INFO |   Batch 1400 / 5959: loss=0.793128 cross_entropy_loss=10.317462
# 2026-04-21,03:46:37 | INFO |   Batch 1600 / 5959: loss=0.785057 cross_entropy_loss=10.281402
# 2026-04-21,03:46:39 | INFO |   Batch 1800 / 5959: loss=0.780829 cross_entropy_loss=10.272966
# 2026-04-21,03:46:40 | INFO |   Batch 2000 / 5959: loss=0.846261 cross_entropy_loss=10.975375
# 2026-04-21,03:46:42 | INFO |   Batch 2200 / 5959: loss=0.753635 cross_entropy_loss=9.986279
# 2026-04-21,03:46:43 | INFO |   Batch 2400 / 5959: loss=0.820915 cross_entropy_loss=10.729010
# 2026-04-21,03:46:45 | INFO |   Batch 2600 / 5959: loss=0.759172 cross_entropy_loss=9.939469
# 2026-04-21,03:46:47 | INFO |   Batch 2800 / 5959: loss=0.766129 cross_entropy_loss=10.044201
# 2026-04-21,03:46:48 | INFO |   Batch 3000 / 5959: loss=0.804270 cross_entropy_loss=10.381266
# 2026-04-21,03:46:50 | INFO |   Batch 3200 / 5959: loss=0.766818 cross_entropy_loss=10.213454
# 2026-04-21,03:46:52 | INFO |   Batch 3400 / 5959: loss=0.751441 cross_entropy_loss=10.076797
# 2026-04-21,03:46:53 | INFO |   Batch 3600 / 5959: loss=0.789241 cross_entropy_loss=10.483664
# 2026-04-21,03:46:55 | INFO |   Batch 3800 / 5959: loss=0.803427 cross_entropy_loss=10.699341
# 2026-04-21,03:46:56 | INFO |   Batch 4000 / 5959: loss=0.792684 cross_entropy_loss=10.777597
# 2026-04-21,03:46:58 | INFO |   Batch 4200 / 5959: loss=0.799518 cross_entropy_loss=10.762238
# 2026-04-21,03:47:00 | INFO |   Batch 4400 / 5959: loss=0.799686 cross_entropy_loss=10.615076
# 2026-04-21,03:47:01 | INFO |   Batch 4600 / 5959: loss=0.800377 cross_entropy_loss=10.552518
# 2026-04-21,03:47:03 | INFO |   Batch 4800 / 5959: loss=0.770540 cross_entropy_loss=10.532592
# 2026-04-21,03:47:05 | INFO |   Batch 5000 / 5959: loss=0.746548 cross_entropy_loss=10.182037
# 2026-04-21,03:47:06 | INFO |   Batch 5200 / 5959: loss=0.741174 cross_entropy_loss=10.038019
# 2026-04-21,03:47:08 | INFO |   Batch 5400 / 5959: loss=0.782975 cross_entropy_loss=10.453983
# 2026-04-21,03:47:09 | INFO |   Batch 5600 / 5959: loss=0.773765 cross_entropy_loss=10.327207
# 2026-04-21,03:47:11 | INFO |   Batch 5800 / 5959: loss=0.768764 cross_entropy_loss=10.472527
# 2026-04-21,03:47:12 | INFO | Evaluating on validation set
# 2026-04-21,03:47:12 | INFO |   Batch 0 / 745: loss=10.495344
# 2026-04-21,03:47:13 | INFO |   Batch 200 / 745: loss=10.382103
# 2026-04-21,03:47:13 | INFO |   Batch 400 / 745: loss=10.638006
# 2026-04-21,03:47:13 | INFO |   Batch 600 / 745: loss=10.277428
# 2026-04-21,03:47:14 | INFO | exp4_cfg01_scent_ref | epoch=5 train_ce=10.435301 val_loss=10.477075 val_acc=0.203711 best_val_acc=0.203711 best_test_acc=0.000000
# 2026-04-21,03:47:14 | INFO | exp4_cfg01_scent_ref | Epoch 6/20, learning_rate=0.001588
# 2026-04-21,03:47:14 | INFO |   Batch 0 / 5959: loss=0.802965 cross_entropy_loss=10.074395
# 2026-04-21,03:47:16 | INFO |   Batch 200 / 5959: loss=0.815048 cross_entropy_loss=10.234497
# 2026-04-21,03:47:18 | INFO |   Batch 400 / 5959: loss=0.831137 cross_entropy_loss=10.514886
# 2026-04-21,03:47:19 | INFO |   Batch 600 / 5959: loss=0.802480 cross_entropy_loss=10.142779
# 2026-04-21,03:47:21 | INFO |   Batch 800 / 5959: loss=0.824772 cross_entropy_loss=10.434990
# 2026-04-21,03:47:22 | INFO |   Batch 1000 / 5959: loss=0.829448 cross_entropy_loss=10.478239
# 2026-04-21,03:47:24 | INFO |   Batch 1200 / 5959: loss=0.794827 cross_entropy_loss=9.977102
# 2026-04-21,03:47:26 | INFO |   Batch 1400 / 5959: loss=0.830717 cross_entropy_loss=10.564376
# 2026-04-21,03:47:27 | INFO |   Batch 1600 / 5959: loss=0.824013 cross_entropy_loss=10.419312
# 2026-04-21,03:47:29 | INFO |   Batch 1800 / 5959: loss=0.790188 cross_entropy_loss=10.011724
# 2026-04-21,03:47:31 | INFO |   Batch 2000 / 5959: loss=0.779836 cross_entropy_loss=10.071330
# 2026-04-21,03:47:32 | INFO |   Batch 2200 / 5959: loss=0.818119 cross_entropy_loss=10.515519
# 2026-04-21,03:47:34 | INFO |   Batch 2400 / 5959: loss=0.846866 cross_entropy_loss=10.893484
# 2026-04-21,03:47:35 | INFO |   Batch 2600 / 5959: loss=0.820045 cross_entropy_loss=10.435400
# 2026-04-21,03:47:37 | INFO |   Batch 2800 / 5959: loss=0.782267 cross_entropy_loss=10.157652
# 2026-04-21,03:47:39 | INFO |   Batch 3000 / 5959: loss=0.791182 cross_entropy_loss=10.280627
# 2026-04-21,03:47:40 | INFO |   Batch 3200 / 5959: loss=0.756061 cross_entropy_loss=10.077522
# 2026-04-21,03:47:42 | INFO |   Batch 3400 / 5959: loss=0.818306 cross_entropy_loss=10.514751
# 2026-04-21,03:47:44 | INFO |   Batch 3600 / 5959: loss=0.755987 cross_entropy_loss=10.017818
# 2026-04-21,03:47:45 | INFO |   Batch 3800 / 5959: loss=0.829708 cross_entropy_loss=10.735147
# 2026-04-21,03:47:47 | INFO |   Batch 4000 / 5959: loss=0.777855 cross_entropy_loss=10.225044
# 2026-04-21,03:47:48 | INFO |   Batch 4200 / 5959: loss=0.771403 cross_entropy_loss=10.041752
# 2026-04-21,03:47:50 | INFO |   Batch 4400 / 5959: loss=0.800601 cross_entropy_loss=10.443749
# 2026-04-21,03:47:52 | INFO |   Batch 4600 / 5959: loss=0.785824 cross_entropy_loss=10.364118
# 2026-04-21,03:47:53 | INFO |   Batch 4800 / 5959: loss=0.808079 cross_entropy_loss=10.464768
# 2026-04-21,03:47:55 | INFO |   Batch 5000 / 5959: loss=0.753241 cross_entropy_loss=10.159372
# 2026-04-21,03:47:56 | INFO |   Batch 5200 / 5959: loss=0.800872 cross_entropy_loss=10.471233
# 2026-04-21,03:47:58 | INFO |   Batch 5400 / 5959: loss=0.783085 cross_entropy_loss=10.292212
# 2026-04-21,03:48:00 | INFO |   Batch 5600 / 5959: loss=0.775153 cross_entropy_loss=10.365829
# 2026-04-21,03:48:01 | INFO |   Batch 5800 / 5959: loss=0.740532 cross_entropy_loss=10.072925
# 2026-04-21,03:48:03 | INFO | Evaluating on validation set
# 2026-04-21,03:48:03 | INFO |   Batch 0 / 745: loss=10.363359
# 2026-04-21,03:48:03 | INFO |   Batch 200 / 745: loss=10.246405
# 2026-04-21,03:48:03 | INFO |   Batch 400 / 745: loss=10.511670
# 2026-04-21,03:48:04 | INFO |   Batch 600 / 745: loss=10.134382
# 2026-04-21,03:48:04 | INFO | exp4_cfg01_scent_ref | epoch=6 train_ce=10.269026 val_loss=10.347315 val_acc=0.219719 best_val_acc=0.219719 best_test_acc=0.000000
# 2026-04-21,03:48:05 | INFO | exp4_cfg01_scent_ref | Epoch 7/20, learning_rate=0.001454
# 2026-04-21,03:48:05 | INFO |   Batch 0 / 5959: loss=0.842001 cross_entropy_loss=10.439394
# 2026-04-21,03:48:06 | INFO |   Batch 200 / 5959: loss=0.793173 cross_entropy_loss=9.744376
# 2026-04-21,03:48:08 | INFO |   Batch 400 / 5959: loss=0.804677 cross_entropy_loss=9.942057
# 2026-04-21,03:48:10 | INFO |   Batch 600 / 5959: loss=0.817039 cross_entropy_loss=10.154156
# 2026-04-21,03:48:11 | INFO |   Batch 800 / 5959: loss=0.847514 cross_entropy_loss=10.415573
# 2026-04-21,03:48:13 | INFO |   Batch 1000 / 5959: loss=0.808703 cross_entropy_loss=10.255308
# 2026-04-21,03:48:14 | INFO |   Batch 1200 / 5959: loss=0.835594 cross_entropy_loss=10.401423
# 2026-04-21,03:48:16 | INFO |   Batch 1400 / 5959: loss=0.810182 cross_entropy_loss=10.118061
# 2026-04-21,03:48:18 | INFO |   Batch 1600 / 5959: loss=0.799034 cross_entropy_loss=10.185900
# 2026-04-21,03:48:19 | INFO |   Batch 1800 / 5959: loss=0.757569 cross_entropy_loss=9.856638
# 2026-04-21,03:48:21 | INFO |   Batch 2000 / 5959: loss=0.774708 cross_entropy_loss=9.806942
# 2026-04-21,03:48:22 | INFO |   Batch 2200 / 5959: loss=0.738012 cross_entropy_loss=9.290932
# 2026-04-21,03:48:24 | INFO |   Batch 2400 / 5959: loss=0.831431 cross_entropy_loss=10.333439
# 2026-04-21,03:48:26 | INFO |   Batch 2600 / 5959: loss=0.833359 cross_entropy_loss=10.292167
# 2026-04-21,03:48:27 | INFO |   Batch 2800 / 5959: loss=0.847673 cross_entropy_loss=10.336864
# 2026-04-21,03:48:29 | INFO |   Batch 3000 / 5959: loss=0.812316 cross_entropy_loss=10.432503
# 2026-04-21,03:48:31 | INFO |   Batch 3200 / 5959: loss=0.873272 cross_entropy_loss=10.649296
# 2026-04-21,03:48:32 | INFO |   Batch 3400 / 5959: loss=0.825254 cross_entropy_loss=10.529377
# 2026-04-21,03:48:34 | INFO |   Batch 3600 / 5959: loss=0.806477 cross_entropy_loss=10.207486
# 2026-04-21,03:48:35 | INFO |   Batch 3800 / 5959: loss=0.732866 cross_entropy_loss=9.497898
# 2026-04-21,03:48:37 | INFO |   Batch 4000 / 5959: loss=0.780046 cross_entropy_loss=10.052145
# 2026-04-21,03:48:39 | INFO |   Batch 4200 / 5959: loss=0.793671 cross_entropy_loss=10.125839
# 2026-04-21,03:48:40 | INFO |   Batch 4400 / 5959: loss=0.807356 cross_entropy_loss=10.188051
# 2026-04-21,03:48:42 | INFO |   Batch 4600 / 5959: loss=0.789905 cross_entropy_loss=10.129363
# 2026-04-21,03:48:44 | INFO |   Batch 4800 / 5959: loss=0.777047 cross_entropy_loss=9.952198
# 2026-04-21,03:48:45 | INFO |   Batch 5000 / 5959: loss=0.783732 cross_entropy_loss=9.876093
# 2026-04-21,03:48:47 | INFO |   Batch 5200 / 5959: loss=0.748385 cross_entropy_loss=9.719610
# 2026-04-21,03:48:48 | INFO |   Batch 5400 / 5959: loss=0.791272 cross_entropy_loss=10.225124
# 2026-04-21,03:48:50 | INFO |   Batch 5600 / 5959: loss=0.777480 cross_entropy_loss=10.012289
# 2026-04-21,03:48:52 | INFO |   Batch 5800 / 5959: loss=0.761310 cross_entropy_loss=9.970141
# 2026-04-21,03:48:53 | INFO | Evaluating on validation set
# 2026-04-21,03:48:53 | INFO |   Batch 0 / 745: loss=10.243515
# 2026-04-21,03:48:53 | INFO |   Batch 200 / 745: loss=10.124310
# 2026-04-21,03:48:54 | INFO |   Batch 400 / 745: loss=10.398609
# 2026-04-21,03:48:54 | INFO |   Batch 600 / 745: loss=10.003947
# 2026-04-21,03:48:54 | INFO | exp4_cfg01_scent_ref | epoch=7 train_ce=10.117261 val_loss=10.230870 val_acc=0.231971 best_val_acc=0.231971 best_test_acc=0.000000
# 2026-04-21,03:48:55 | INFO | exp4_cfg01_scent_ref | Epoch 8/20, learning_rate=0.001309
# 2026-04-21,03:48:55 | INFO |   Batch 0 / 5959: loss=0.803933 cross_entropy_loss=9.894827
# 2026-04-21,03:48:57 | INFO |   Batch 200 / 5959: loss=0.814360 cross_entropy_loss=9.877008
# 2026-04-21,03:48:58 | INFO |   Batch 400 / 5959: loss=0.806582 cross_entropy_loss=9.882469
# 2026-04-21,03:49:00 | INFO |   Batch 600 / 5959: loss=0.821237 cross_entropy_loss=9.910933
# 2026-04-21,03:49:01 | INFO |   Batch 800 / 5959: loss=0.797883 cross_entropy_loss=9.859020
# 2026-04-21,03:49:03 | INFO |   Batch 1000 / 5959: loss=0.857785 cross_entropy_loss=10.295575
# 2026-04-21,03:49:05 | INFO |   Batch 1200 / 5959: loss=0.851097 cross_entropy_loss=10.313445
# 2026-04-21,03:49:06 | INFO |   Batch 1400 / 5959: loss=0.800901 cross_entropy_loss=10.000129
# 2026-04-21,03:49:08 | INFO |   Batch 1600 / 5959: loss=0.819803 cross_entropy_loss=10.017732
# 2026-04-21,03:49:10 | INFO |   Batch 1800 / 5959: loss=0.773040 cross_entropy_loss=9.553582
# 2026-04-21,03:49:11 | INFO |   Batch 2000 / 5959: loss=0.779012 cross_entropy_loss=9.532089
# 2026-04-21,03:49:13 | INFO |   Batch 2200 / 5959: loss=0.787152 cross_entropy_loss=9.965660
# 2026-04-21,03:49:14 | INFO |   Batch 2400 / 5959: loss=0.792794 cross_entropy_loss=10.073435
# 2026-04-21,03:49:16 | INFO |   Batch 2600 / 5959: loss=0.780285 cross_entropy_loss=9.726174
# 2026-04-21,03:49:18 | INFO |   Batch 2800 / 5959: loss=0.782401 cross_entropy_loss=9.665508
# 2026-04-21,03:49:19 | INFO |   Batch 3000 / 5959: loss=0.813901 cross_entropy_loss=10.015165
# 2026-04-21,03:49:21 | INFO |   Batch 3200 / 5959: loss=0.825736 cross_entropy_loss=10.035322
# 2026-04-21,03:49:22 | INFO |   Batch 3400 / 5959: loss=0.791912 cross_entropy_loss=9.925390
# 2026-04-21,03:49:24 | INFO |   Batch 3600 / 5959: loss=0.794572 cross_entropy_loss=9.508490
# 2026-04-21,03:49:26 | INFO |   Batch 3800 / 5959: loss=0.837415 cross_entropy_loss=10.615826
# 2026-04-21,03:49:27 | INFO |   Batch 4000 / 5959: loss=0.816594 cross_entropy_loss=10.180469
# 2026-04-21,03:49:29 | INFO |   Batch 4200 / 5959: loss=0.803005 cross_entropy_loss=10.161705
# 2026-04-21,03:49:31 | INFO |   Batch 4400 / 5959: loss=0.781492 cross_entropy_loss=9.853863
# 2026-04-21,03:49:32 | INFO |   Batch 4600 / 5959: loss=0.766121 cross_entropy_loss=9.611334
# 2026-04-21,03:49:34 | INFO |   Batch 4800 / 5959: loss=0.815722 cross_entropy_loss=10.250955
# 2026-04-21,03:49:35 | INFO |   Batch 5000 / 5959: loss=0.752343 cross_entropy_loss=9.496757
# 2026-04-21,03:49:37 | INFO |   Batch 5200 / 5959: loss=0.792597 cross_entropy_loss=9.722125
# 2026-04-21,03:49:39 | INFO |   Batch 5400 / 5959: loss=0.798212 cross_entropy_loss=10.085639
# 2026-04-21,03:49:40 | INFO |   Batch 5600 / 5959: loss=0.760549 cross_entropy_loss=9.744238
# 2026-04-21,03:49:42 | INFO |   Batch 5800 / 5959: loss=0.770236 cross_entropy_loss=9.823409
# 2026-04-21,03:49:43 | INFO | Evaluating on validation set
# 2026-04-21,03:49:43 | INFO |   Batch 0 / 745: loss=10.137298
# 2026-04-21,03:49:44 | INFO |   Batch 200 / 745: loss=10.017174
# 2026-04-21,03:49:44 | INFO |   Batch 400 / 745: loss=10.298594
# 2026-04-21,03:49:44 | INFO |   Batch 600 / 745: loss=9.888208
# 2026-04-21,03:49:45 | INFO | exp4_cfg01_scent_ref | epoch=8 train_ce=9.980554 val_loss=10.127813 val_acc=0.241160 best_val_acc=0.241160 best_test_acc=0.000000
# 2026-04-21,03:49:45 | INFO | exp4_cfg01_scent_ref | Epoch 9/20, learning_rate=0.001156
# 2026-04-21,03:49:45 | INFO |   Batch 0 / 5959: loss=0.814049 cross_entropy_loss=9.584797
# 2026-04-21,03:49:47 | INFO |   Batch 200 / 5959: loss=0.840053 cross_entropy_loss=9.982426
# 2026-04-21,03:49:48 | INFO |   Batch 400 / 5959: loss=0.818882 cross_entropy_loss=9.543200
# 2026-04-21,03:49:50 | INFO |   Batch 600 / 5959: loss=0.820939 cross_entropy_loss=9.531893
# 2026-04-21,03:49:52 | INFO |   Batch 800 / 5959: loss=0.834508 cross_entropy_loss=10.036320
# 2026-04-21,03:49:53 | INFO |   Batch 1000 / 5959: loss=0.811906 cross_entropy_loss=9.806481
# 2026-04-21,03:49:55 | INFO |   Batch 1200 / 5959: loss=0.814896 cross_entropy_loss=9.964996
# 2026-04-21,03:49:57 | INFO |   Batch 1400 / 5959: loss=0.811174 cross_entropy_loss=9.760032
# 2026-04-21,03:49:58 | INFO |   Batch 1600 / 5959: loss=0.808770 cross_entropy_loss=9.723774
# 2026-04-21,03:50:00 | INFO |   Batch 1800 / 5959: loss=0.809774 cross_entropy_loss=9.579210
# 2026-04-21,03:50:01 | INFO |   Batch 2000 / 5959: loss=0.827916 cross_entropy_loss=10.062211
# 2026-04-21,03:50:03 | INFO |   Batch 2200 / 5959: loss=0.797148 cross_entropy_loss=9.591767
# 2026-04-21,03:50:05 | INFO |   Batch 2400 / 5959: loss=0.815639 cross_entropy_loss=9.738515
# 2026-04-21,03:50:06 | INFO |   Batch 2600 / 5959: loss=0.807970 cross_entropy_loss=9.827997
# 2026-04-21,03:50:08 | INFO |   Batch 2800 / 5959: loss=0.832462 cross_entropy_loss=10.042686
# 2026-04-21,03:50:09 | INFO |   Batch 3000 / 5959: loss=0.795067 cross_entropy_loss=9.685842
# 2026-04-21,03:50:11 | INFO |   Batch 3200 / 5959: loss=0.832285 cross_entropy_loss=10.055426
# 2026-04-21,03:50:13 | INFO |   Batch 3400 / 5959: loss=0.807499 cross_entropy_loss=10.035097
# 2026-04-21,03:50:14 | INFO |   Batch 3600 / 5959: loss=0.809123 cross_entropy_loss=9.913563
# 2026-04-21,03:50:16 | INFO |   Batch 3800 / 5959: loss=0.813363 cross_entropy_loss=10.022390
# 2026-04-21,03:50:18 | INFO |   Batch 4000 / 5959: loss=0.801624 cross_entropy_loss=9.724337
# 2026-04-21,03:50:19 | INFO |   Batch 4200 / 5959: loss=0.795233 cross_entropy_loss=10.001760
# 2026-04-21,03:50:21 | INFO |   Batch 4400 / 5959: loss=0.802656 cross_entropy_loss=10.027864
# 2026-04-21,03:50:22 | INFO |   Batch 4600 / 5959: loss=0.799770 cross_entropy_loss=9.653533
# 2026-04-21,03:50:24 | INFO |   Batch 4800 / 5959: loss=0.770020 cross_entropy_loss=9.551645
# 2026-04-21,03:50:26 | INFO |   Batch 5000 / 5959: loss=0.759257 cross_entropy_loss=9.460572
# 2026-04-21,03:50:27 | INFO |   Batch 5200 / 5959: loss=0.857338 cross_entropy_loss=10.296247
# 2026-04-21,03:50:29 | INFO |   Batch 5400 / 5959: loss=0.802612 cross_entropy_loss=9.824120
# 2026-04-21,03:50:31 | INFO |   Batch 5600 / 5959: loss=0.808183 cross_entropy_loss=9.968161
# 2026-04-21,03:50:32 | INFO |   Batch 5800 / 5959: loss=0.755492 cross_entropy_loss=9.306845
# 2026-04-21,03:50:33 | INFO | Evaluating on validation set
# 2026-04-21,03:50:33 | INFO |   Batch 0 / 745: loss=10.043571
# 2026-04-21,03:50:34 | INFO |   Batch 200 / 745: loss=9.923529
# 2026-04-21,03:50:34 | INFO |   Batch 400 / 745: loss=10.211010
# 2026-04-21,03:50:35 | INFO |   Batch 600 / 745: loss=9.786406
# 2026-04-21,03:50:35 | INFO | exp4_cfg01_scent_ref | epoch=9 train_ce=9.859628 val_loss=10.038026 val_acc=0.247579 best_val_acc=0.247579 best_test_acc=0.000000
# 2026-04-21,03:50:36 | INFO | exp4_cfg01_scent_ref | Epoch 10/20, learning_rate=0.001000
# 2026-04-21,03:50:36 | INFO |   Batch 0 / 5959: loss=0.821274 cross_entropy_loss=9.692486
# 2026-04-21,03:50:37 | INFO |   Batch 200 / 5959: loss=0.860120 cross_entropy_loss=9.958517
# 2026-04-21,03:50:39 | INFO |   Batch 400 / 5959: loss=0.841585 cross_entropy_loss=9.961063
# 2026-04-21,03:50:40 | INFO |   Batch 600 / 5959: loss=0.810620 cross_entropy_loss=9.524708
# 2026-04-21,03:50:42 | INFO |   Batch 800 / 5959: loss=0.799322 cross_entropy_loss=9.529127
# 2026-04-21,03:50:44 | INFO |   Batch 1000 / 5959: loss=0.819050 cross_entropy_loss=9.520977
# 2026-04-21,03:50:45 | INFO |   Batch 1200 / 5959: loss=0.812868 cross_entropy_loss=9.570644
# 2026-04-21,03:50:47 | INFO |   Batch 1400 / 5959: loss=0.821772 cross_entropy_loss=9.601743
# 2026-04-21,03:50:49 | INFO |   Batch 1600 / 5959: loss=0.860861 cross_entropy_loss=9.946680
# 2026-04-21,03:50:50 | INFO |   Batch 1800 / 5959: loss=0.830622 cross_entropy_loss=9.791850
# 2026-04-21,03:50:52 | INFO |   Batch 2000 / 5959: loss=0.802827 cross_entropy_loss=9.505051
# 2026-04-21,03:50:53 | INFO |   Batch 2200 / 5959: loss=0.812331 cross_entropy_loss=9.578436
# 2026-04-21,03:50:55 | INFO |   Batch 2400 / 5959: loss=0.828137 cross_entropy_loss=9.842325
# 2026-04-21,03:50:57 | INFO |   Batch 2600 / 5959: loss=0.848806 cross_entropy_loss=10.193680
# 2026-04-21,03:50:58 | INFO |   Batch 2800 / 5959: loss=0.806568 cross_entropy_loss=9.786741
# 2026-04-21,03:51:00 | INFO |   Batch 3000 / 5959: loss=0.787941 cross_entropy_loss=9.630325
# 2026-04-21,03:51:01 | INFO |   Batch 3200 / 5959: loss=0.822028 cross_entropy_loss=9.736471
# 2026-04-21,03:51:03 | INFO |   Batch 3400 / 5959: loss=0.773787 cross_entropy_loss=9.150509
# 2026-04-21,03:51:05 | INFO |   Batch 3600 / 5959: loss=0.767155 cross_entropy_loss=9.011980
# 2026-04-21,03:51:06 | INFO |   Batch 3800 / 5959: loss=0.752906 cross_entropy_loss=8.978172
# 2026-04-21,03:51:08 | INFO |   Batch 4000 / 5959: loss=0.842667 cross_entropy_loss=10.117513
# 2026-04-21,03:51:10 | INFO |   Batch 4200 / 5959: loss=0.834753 cross_entropy_loss=9.921980
# 2026-04-21,03:51:11 | INFO |   Batch 4400 / 5959: loss=0.819446 cross_entropy_loss=9.828587
# 2026-04-21,03:51:13 | INFO |   Batch 4600 / 5959: loss=0.793240 cross_entropy_loss=9.522588
# 2026-04-21,03:51:14 | INFO |   Batch 4800 / 5959: loss=0.851441 cross_entropy_loss=9.932740
# 2026-04-21,03:51:16 | INFO |   Batch 5000 / 5959: loss=0.807456 cross_entropy_loss=9.489860
# 2026-04-21,03:51:18 | INFO |   Batch 5200 / 5959: loss=0.799786 cross_entropy_loss=9.693677
# 2026-04-21,03:51:19 | INFO |   Batch 5400 / 5959: loss=0.826578 cross_entropy_loss=10.054284
# 2026-04-21,03:51:21 | INFO |   Batch 5600 / 5959: loss=0.834196 cross_entropy_loss=9.739857
# 2026-04-21,03:51:22 | INFO |   Batch 5800 / 5959: loss=0.797636 cross_entropy_loss=9.893465
# 2026-04-21,03:51:24 | INFO | Evaluating on validation set
# 2026-04-21,03:51:24 | INFO |   Batch 0 / 745: loss=9.962767
# 2026-04-21,03:51:24 | INFO |   Batch 200 / 745: loss=9.843855
# 2026-04-21,03:51:25 | INFO |   Batch 400 / 745: loss=10.135602
# 2026-04-21,03:51:25 | INFO |   Batch 600 / 745: loss=9.698885
# 2026-04-21,03:51:25 | INFO | exp4_cfg01_scent_ref | epoch=10 train_ce=9.754419 val_loss=9.961120 val_acc=0.251576 best_val_acc=0.251576 best_test_acc=0.000000
# 2026-04-21,03:51:26 | INFO | exp4_cfg01_scent_ref | Epoch 11/20, learning_rate=0.000844
# 2026-04-21,03:51:26 | INFO |   Batch 0 / 5959: loss=0.847911 cross_entropy_loss=9.671701
# 2026-04-21,03:51:27 | INFO |   Batch 200 / 5959: loss=0.847567 cross_entropy_loss=9.628657
# 2026-04-21,03:51:29 | INFO |   Batch 400 / 5959: loss=0.864729 cross_entropy_loss=9.666969
# 2026-04-21,03:51:31 | INFO |   Batch 600 / 5959: loss=0.846722 cross_entropy_loss=9.822723
# 2026-04-21,03:51:32 | INFO |   Batch 800 / 5959: loss=0.828375 cross_entropy_loss=9.408837
# 2026-04-21,03:51:34 | INFO |   Batch 1000 / 5959: loss=0.836660 cross_entropy_loss=9.514469
# 2026-04-21,03:51:35 | INFO |   Batch 1200 / 5959: loss=0.826857 cross_entropy_loss=9.372521
# 2026-04-21,03:51:37 | INFO |   Batch 1400 / 5959: loss=0.839257 cross_entropy_loss=9.622109
# 2026-04-21,03:51:39 | INFO |   Batch 1600 / 5959: loss=0.874138 cross_entropy_loss=10.146894
# 2026-04-21,03:51:40 | INFO |   Batch 1800 / 5959: loss=0.891237 cross_entropy_loss=10.210163
# 2026-04-21,03:51:42 | INFO |   Batch 2000 / 5959: loss=0.859383 cross_entropy_loss=9.993989
# 2026-04-21,03:51:44 | INFO |   Batch 2200 / 5959: loss=0.795287 cross_entropy_loss=9.236174
# 2026-04-21,03:51:45 | INFO |   Batch 2400 / 5959: loss=0.835573 cross_entropy_loss=9.885353
# 2026-04-21,03:51:47 | INFO |   Batch 2600 / 5959: loss=0.803768 cross_entropy_loss=9.319895
# 2026-04-21,03:51:48 | INFO |   Batch 2800 / 5959: loss=0.798129 cross_entropy_loss=9.403896
# 2026-04-21,03:51:50 | INFO |   Batch 3000 / 5959: loss=0.833691 cross_entropy_loss=9.796061
# 2026-04-21,03:51:52 | INFO |   Batch 3200 / 5959: loss=0.824297 cross_entropy_loss=9.948642
# 2026-04-21,03:51:53 | INFO |   Batch 3400 / 5959: loss=0.839790 cross_entropy_loss=9.533728
# 2026-04-21,03:51:55 | INFO |   Batch 3600 / 5959: loss=0.808416 cross_entropy_loss=9.539032
# 2026-04-21,03:51:57 | INFO |   Batch 3800 / 5959: loss=0.815760 cross_entropy_loss=9.349485
# 2026-04-21,03:51:58 | INFO |   Batch 4000 / 5959: loss=0.798728 cross_entropy_loss=9.347180
# 2026-04-21,03:52:00 | INFO |   Batch 4200 / 5959: loss=0.808541 cross_entropy_loss=9.198914
# 2026-04-21,03:52:01 | INFO |   Batch 4400 / 5959: loss=0.847043 cross_entropy_loss=9.611909
# 2026-04-21,03:52:03 | INFO |   Batch 4600 / 5959: loss=0.875562 cross_entropy_loss=10.178015
# 2026-04-21,03:52:05 | INFO |   Batch 4800 / 5959: loss=0.843385 cross_entropy_loss=9.739603
# 2026-04-21,03:52:06 | INFO |   Batch 5000 / 5959: loss=0.786065 cross_entropy_loss=9.414461
# 2026-04-21,03:52:08 | INFO |   Batch 5200 / 5959: loss=0.856915 cross_entropy_loss=10.266920
# 2026-04-21,03:52:09 | INFO |   Batch 5400 / 5959: loss=0.795008 cross_entropy_loss=9.600679
# 2026-04-21,03:52:11 | INFO |   Batch 5600 / 5959: loss=0.806959 cross_entropy_loss=9.578173
# 2026-04-21,03:52:13 | INFO |   Batch 5800 / 5959: loss=0.831623 cross_entropy_loss=9.699842
# 2026-04-21,03:52:14 | INFO | Evaluating on validation set
# 2026-04-21,03:52:14 | INFO |   Batch 0 / 745: loss=9.894966
# 2026-04-21,03:52:14 | INFO |   Batch 200 / 745: loss=9.777973
# 2026-04-21,03:52:15 | INFO |   Batch 400 / 745: loss=10.072181
# 2026-04-21,03:52:15 | INFO |   Batch 600 / 745: loss=9.624590
# 2026-04-21,03:52:15 | INFO | exp4_cfg01_scent_ref | epoch=11 train_ce=9.664405 val_loss=9.896481 val_acc=0.254912 best_val_acc=0.254912 best_test_acc=0.000000
# 2026-04-21,03:52:16 | INFO | exp4_cfg01_scent_ref | Epoch 12/20, learning_rate=0.000691
# 2026-04-21,03:52:16 | INFO |   Batch 0 / 5959: loss=0.839622 cross_entropy_loss=9.526377
# 2026-04-21,03:52:18 | INFO |   Batch 200 / 5959: loss=0.875608 cross_entropy_loss=9.997638
# 2026-04-21,03:52:19 | INFO |   Batch 400 / 5959: loss=0.863237 cross_entropy_loss=9.740856
# 2026-04-21,03:52:21 | INFO |   Batch 600 / 5959: loss=0.843942 cross_entropy_loss=9.404526
# 2026-04-21,03:52:22 | INFO |   Batch 800 / 5959: loss=0.838778 cross_entropy_loss=9.543562
# 2026-04-21,03:52:24 | INFO |   Batch 1000 / 5959: loss=0.854378 cross_entropy_loss=9.596668
# 2026-04-21,03:52:26 | INFO |   Batch 1200 / 5959: loss=0.856434 cross_entropy_loss=9.475936
# 2026-04-21,03:52:27 | INFO |   Batch 1400 / 5959: loss=0.853777 cross_entropy_loss=9.628263
# 2026-04-21,03:52:29 | INFO |   Batch 1600 / 5959: loss=0.884883 cross_entropy_loss=9.998498
# 2026-04-21,03:52:31 | INFO |   Batch 1800 / 5959: loss=0.900106 cross_entropy_loss=10.194680
# 2026-04-21,03:52:32 | INFO |   Batch 2000 / 5959: loss=0.872631 cross_entropy_loss=9.820776
# 2026-04-21,03:52:34 | INFO |   Batch 2200 / 5959: loss=0.896598 cross_entropy_loss=10.152981
# 2026-04-21,03:52:35 | INFO |   Batch 2400 / 5959: loss=0.868040 cross_entropy_loss=9.879642
# 2026-04-21,03:52:37 | INFO |   Batch 2600 / 5959: loss=0.833250 cross_entropy_loss=9.269092
# 2026-04-21,03:52:39 | INFO |   Batch 2800 / 5959: loss=0.852034 cross_entropy_loss=9.615511
# 2026-04-21,03:52:40 | INFO |   Batch 3000 / 5959: loss=0.822085 cross_entropy_loss=9.476547
# 2026-04-21,03:52:42 | INFO |   Batch 3200 / 5959: loss=0.851025 cross_entropy_loss=9.572487
# 2026-04-21,03:52:43 | INFO |   Batch 3400 / 5959: loss=0.839213 cross_entropy_loss=9.321974
# 2026-04-21,03:52:45 | INFO |   Batch 3600 / 5959: loss=0.866820 cross_entropy_loss=9.821463
# 2026-04-21,03:52:47 | INFO |   Batch 3800 / 5959: loss=0.835565 cross_entropy_loss=9.496571
# 2026-04-21,03:52:48 | INFO |   Batch 4000 / 5959: loss=0.828851 cross_entropy_loss=9.194103
# 2026-04-21,03:52:50 | INFO |   Batch 4200 / 5959: loss=0.838180 cross_entropy_loss=9.832127
# 2026-04-21,03:52:52 | INFO |   Batch 4400 / 5959: loss=0.842053 cross_entropy_loss=9.765841
# 2026-04-21,03:52:53 | INFO |   Batch 4600 / 5959: loss=0.848463 cross_entropy_loss=9.706413
# 2026-04-21,03:52:55 | INFO |   Batch 4800 / 5959: loss=0.845874 cross_entropy_loss=9.680647
# 2026-04-21,03:52:56 | INFO |   Batch 5000 / 5959: loss=0.823156 cross_entropy_loss=9.417608
# 2026-04-21,03:52:58 | INFO |   Batch 5200 / 5959: loss=0.838769 cross_entropy_loss=9.753489
# 2026-04-21,03:53:00 | INFO |   Batch 5400 / 5959: loss=0.840748 cross_entropy_loss=9.344141
# 2026-04-21,03:53:01 | INFO |   Batch 5600 / 5959: loss=0.813659 cross_entropy_loss=9.446707
# 2026-04-21,03:53:03 | INFO |   Batch 5800 / 5959: loss=0.830652 cross_entropy_loss=9.456389
# 2026-04-21,03:53:04 | INFO | Evaluating on validation set
# 2026-04-21,03:53:04 | INFO |   Batch 0 / 745: loss=9.838254
# 2026-04-21,03:53:05 | INFO |   Batch 200 / 745: loss=9.723580
# 2026-04-21,03:53:05 | INFO |   Batch 400 / 745: loss=10.020231
# 2026-04-21,03:53:05 | INFO |   Batch 600 / 745: loss=9.563027
# 2026-04-21,03:53:06 | INFO | exp4_cfg01_scent_ref | epoch=12 train_ce=9.589085 val_loss=9.843273 val_acc=0.256863 best_val_acc=0.256863 best_test_acc=0.000000
# 2026-04-21,03:53:06 | INFO | exp4_cfg01_scent_ref | Epoch 13/20, learning_rate=0.000546
# 2026-04-21,03:53:06 | INFO |   Batch 0 / 5959: loss=0.882255 cross_entropy_loss=9.678823
# 2026-04-21,03:53:08 | INFO |   Batch 200 / 5959: loss=0.859106 cross_entropy_loss=9.379744
# 2026-04-21,03:53:09 | INFO |   Batch 400 / 5959: loss=0.840717 cross_entropy_loss=9.242764
# 2026-04-21,03:53:11 | INFO |   Batch 600 / 5959: loss=0.900422 cross_entropy_loss=9.807887
# 2026-04-21,03:53:13 | INFO |   Batch 800 / 5959: loss=0.868697 cross_entropy_loss=9.618990
# 2026-04-21,03:53:14 | INFO |   Batch 1000 / 5959: loss=0.888131 cross_entropy_loss=9.616261
# 2026-04-21,03:53:16 | INFO |   Batch 1200 / 5959: loss=0.872904 cross_entropy_loss=9.694223
# 2026-04-21,03:53:18 | INFO |   Batch 1400 / 5959: loss=0.864549 cross_entropy_loss=9.617572
# 2026-04-21,03:53:19 | INFO |   Batch 1600 / 5959: loss=0.830621 cross_entropy_loss=9.116870
# 2026-04-21,03:53:21 | INFO |   Batch 1800 / 5959: loss=0.864041 cross_entropy_loss=9.685212
# 2026-04-21,03:53:22 | INFO |   Batch 2000 / 5959: loss=0.856136 cross_entropy_loss=9.418846
# 2026-04-21,03:53:24 | INFO |   Batch 2200 / 5959: loss=0.855494 cross_entropy_loss=9.492998
# 2026-04-21,03:53:26 | INFO |   Batch 2400 / 5959: loss=0.854325 cross_entropy_loss=9.296414
# 2026-04-21,03:53:27 | INFO |   Batch 2600 / 5959: loss=0.831068 cross_entropy_loss=9.294247
# 2026-04-21,03:53:29 | INFO |   Batch 2800 / 5959: loss=0.880967 cross_entropy_loss=9.750980
# 2026-04-21,03:53:30 | INFO |   Batch 3000 / 5959: loss=0.856365 cross_entropy_loss=9.379307
# 2026-04-21,03:53:32 | INFO |   Batch 3200 / 5959: loss=0.873387 cross_entropy_loss=9.886102
# 2026-04-21,03:53:34 | INFO |   Batch 3400 / 5959: loss=0.848049 cross_entropy_loss=9.530419
# 2026-04-21,03:53:35 | INFO |   Batch 3600 / 5959: loss=0.881349 cross_entropy_loss=9.720205
# 2026-04-21,03:53:37 | INFO |   Batch 3800 / 5959: loss=0.868280 cross_entropy_loss=9.587522
# 2026-04-21,03:53:39 | INFO |   Batch 4000 / 5959: loss=0.880409 cross_entropy_loss=10.027977
# 2026-04-21,03:53:40 | INFO |   Batch 4200 / 5959: loss=0.860163 cross_entropy_loss=9.743064
# 2026-04-21,03:53:42 | INFO |   Batch 4400 / 5959: loss=0.841407 cross_entropy_loss=9.576975
# 2026-04-21,03:53:43 | INFO |   Batch 4600 / 5959: loss=0.828525 cross_entropy_loss=9.373826
# 2026-04-21,03:53:45 | INFO |   Batch 4800 / 5959: loss=0.884650 cross_entropy_loss=9.786436
# 2026-04-21,03:53:47 | INFO |   Batch 5000 / 5959: loss=0.826954 cross_entropy_loss=9.418742
# 2026-04-21,03:53:48 | INFO |   Batch 5200 / 5959: loss=0.841824 cross_entropy_loss=9.471683
# 2026-04-21,03:53:50 | INFO |   Batch 5400 / 5959: loss=0.853193 cross_entropy_loss=9.514040
# 2026-04-21,03:53:52 | INFO |   Batch 5600 / 5959: loss=0.801338 cross_entropy_loss=8.767912
# 2026-04-21,03:53:53 | INFO |   Batch 5800 / 5959: loss=0.853450 cross_entropy_loss=9.527833
# 2026-04-21,03:53:54 | INFO | Evaluating on validation set
# 2026-04-21,03:53:54 | INFO |   Batch 0 / 745: loss=9.792459
# 2026-04-21,03:53:55 | INFO |   Batch 200 / 745: loss=9.680802
# 2026-04-21,03:53:55 | INFO |   Batch 400 / 745: loss=9.978720
# 2026-04-21,03:53:56 | INFO |   Batch 600 / 745: loss=9.513091
# 2026-04-21,03:53:56 | INFO | exp4_cfg01_scent_ref | epoch=13 train_ce=9.527569 val_loss=9.800565 val_acc=0.258038 best_val_acc=0.258038 best_test_acc=0.000000
# 2026-04-21,03:53:56 | INFO | exp4_cfg01_scent_ref | Epoch 14/20, learning_rate=0.000412
# 2026-04-21,03:53:56 | INFO |   Batch 0 / 5959: loss=0.905052 cross_entropy_loss=9.891042
# 2026-04-21,03:53:58 | INFO |   Batch 200 / 5959: loss=0.875578 cross_entropy_loss=9.349657
# 2026-04-21,03:54:00 | INFO |   Batch 400 / 5959: loss=0.858828 cross_entropy_loss=9.310745
# 2026-04-21,03:54:01 | INFO |   Batch 600 / 5959: loss=0.919323 cross_entropy_loss=9.814831
# 2026-04-21,03:54:03 | INFO |   Batch 800 / 5959: loss=0.899003 cross_entropy_loss=9.788909
# 2026-04-21,03:54:05 | INFO |   Batch 1000 / 5959: loss=0.871964 cross_entropy_loss=9.553709
# 2026-04-21,03:54:06 | INFO |   Batch 1200 / 5959: loss=0.844196 cross_entropy_loss=9.335281
# 2026-04-21,03:54:08 | INFO |   Batch 1400 / 5959: loss=0.883115 cross_entropy_loss=9.483504
# 2026-04-21,03:54:09 | INFO |   Batch 1600 / 5959: loss=0.867426 cross_entropy_loss=9.406246
# 2026-04-21,03:54:11 | INFO |   Batch 1800 / 5959: loss=0.853977 cross_entropy_loss=9.271332
# 2026-04-21,03:54:13 | INFO |   Batch 2000 / 5959: loss=0.868768 cross_entropy_loss=9.458508
# 2026-04-21,03:54:14 | INFO |   Batch 2200 / 5959: loss=0.905246 cross_entropy_loss=9.658363
# 2026-04-21,03:54:16 | INFO |   Batch 2400 / 5959: loss=0.875291 cross_entropy_loss=9.386846
# 2026-04-21,03:54:17 | INFO |   Batch 2600 / 5959: loss=0.855556 cross_entropy_loss=8.929480
# 2026-04-21,03:54:19 | INFO |   Batch 2800 / 5959: loss=0.893819 cross_entropy_loss=9.910661
# 2026-04-21,03:54:21 | INFO |   Batch 3000 / 5959: loss=0.827454 cross_entropy_loss=8.831063
# 2026-04-21,03:54:22 | INFO |   Batch 3200 / 5959: loss=0.877543 cross_entropy_loss=9.576990
# 2026-04-21,03:54:24 | INFO |   Batch 3400 / 5959: loss=0.888583 cross_entropy_loss=9.651702
# 2026-04-21,03:54:26 | INFO |   Batch 3600 / 5959: loss=0.880051 cross_entropy_loss=9.670731
# 2026-04-21,03:54:27 | INFO |   Batch 3800 / 5959: loss=0.835773 cross_entropy_loss=9.082273
# 2026-04-21,03:54:29 | INFO |   Batch 4000 / 5959: loss=0.863983 cross_entropy_loss=9.521742
# 2026-04-21,03:54:30 | INFO |   Batch 4200 / 5959: loss=0.870037 cross_entropy_loss=9.456594
# 2026-04-21,03:54:32 | INFO |   Batch 4400 / 5959: loss=0.864092 cross_entropy_loss=9.616299
# 2026-04-21,03:54:34 | INFO |   Batch 4600 / 5959: loss=0.885572 cross_entropy_loss=9.483532
# 2026-04-21,03:54:35 | INFO |   Batch 4800 / 5959: loss=0.874140 cross_entropy_loss=9.637260
# 2026-04-21,03:54:37 | INFO |   Batch 5000 / 5959: loss=0.899060 cross_entropy_loss=9.698488
# 2026-04-21,03:54:39 | INFO |   Batch 5200 / 5959: loss=0.891229 cross_entropy_loss=9.513181
# 2026-04-21,03:54:40 | INFO |   Batch 5400 / 5959: loss=0.888313 cross_entropy_loss=9.750020
# 2026-04-21,03:54:42 | INFO |   Batch 5600 / 5959: loss=0.889605 cross_entropy_loss=9.837393
# 2026-04-21,03:54:43 | INFO |   Batch 5800 / 5959: loss=0.887406 cross_entropy_loss=9.922615
# 2026-04-21,03:54:45 | INFO | Evaluating on validation set
# 2026-04-21,03:54:45 | INFO |   Batch 0 / 745: loss=9.756449
# 2026-04-21,03:54:45 | INFO |   Batch 200 / 745: loss=9.648008
# 2026-04-21,03:54:45 | INFO |   Batch 400 / 745: loss=9.946662
# 2026-04-21,03:54:46 | INFO |   Batch 600 / 745: loss=9.474200
# 2026-04-21,03:54:46 | INFO | exp4_cfg01_scent_ref | epoch=14 train_ce=9.478813 val_loss=9.767521 val_acc=0.258321 best_val_acc=0.258321 best_test_acc=0.000000
# 2026-04-21,03:54:47 | INFO | exp4_cfg01_scent_ref | Epoch 15/20, learning_rate=0.000293
# 2026-04-21,03:54:47 | INFO |   Batch 0 / 5959: loss=0.893552 cross_entropy_loss=9.451433
# 2026-04-21,03:54:48 | INFO |   Batch 200 / 5959: loss=0.869318 cross_entropy_loss=9.181786
# 2026-04-21,03:54:50 | INFO |   Batch 400 / 5959: loss=0.915026 cross_entropy_loss=9.449301
# 2026-04-21,03:54:52 | INFO |   Batch 600 / 5959: loss=0.891744 cross_entropy_loss=9.350088
# 2026-04-21,03:54:53 | INFO |   Batch 800 / 5959: loss=0.930543 cross_entropy_loss=10.024065
# 2026-04-21,03:54:55 | INFO |   Batch 1000 / 5959: loss=0.863383 cross_entropy_loss=8.954318
# 2026-04-21,03:54:56 | INFO |   Batch 1200 / 5959: loss=0.886689 cross_entropy_loss=9.476316
# 2026-04-21,03:54:58 | INFO |   Batch 1400 / 5959: loss=0.850573 cross_entropy_loss=9.140822
# 2026-04-21,03:55:00 | INFO |   Batch 1600 / 5959: loss=0.874545 cross_entropy_loss=9.326138
# 2026-04-21,03:55:01 | INFO |   Batch 1800 / 5959: loss=0.894238 cross_entropy_loss=9.462845
# 2026-04-21,03:55:03 | INFO |   Batch 2000 / 5959: loss=0.853256 cross_entropy_loss=9.040230
# 2026-04-21,03:55:04 | INFO |   Batch 2200 / 5959: loss=0.896503 cross_entropy_loss=9.248244
# 2026-04-21,03:55:06 | INFO |   Batch 2400 / 5959: loss=0.866503 cross_entropy_loss=9.045285
# 2026-04-21,03:55:08 | INFO |   Batch 2600 / 5959: loss=0.863478 cross_entropy_loss=9.251135
# ...
# 2026-04-21,05:05:52 | INFO |   Batch 1400 / 5959: loss=0.647562 cross_entropy_loss=8.917284
# 2026-04-21,05:05:54 | INFO |   Batch 1600 / 5959: loss=0.741329 cross_entropy_loss=8.880219
# 2026-04-21,05:05:56 | INFO |   Batch 1800 / 5959: loss=0.824309 cross_entropy_loss=9.602131
# 2026-04-21,05:05:58 | INFO |   Batch 2000 / 5959: loss=0.643865 cross_entropy_loss=9.167847
# 2026-04-21,05:05:59 | INFO |   Batch 2200 / 5959: loss=0.510147 cross_entropy_loss=9.037498
# 2026-04-21,05:06:01 | INFO |   Batch 2400 / 5959: loss=0.792050 cross_entropy_loss=9.091671
# 2026-04-21,05:06:03 | INFO |   Batch 2600 / 5959: loss=1.179592 cross_entropy_loss=8.987539
# 2026-04-21,05:06:04 | INFO |   Batch 2800 / 5959: loss=1.008885 cross_entropy_loss=7.939720
# 2026-04-21,05:06:06 | INFO |   Batch 3000 / 5959: loss=0.909937 cross_entropy_loss=8.304071
# 2026-04-21,05:06:08 | INFO |   Batch 3200 / 5959: loss=1.032774 cross_entropy_loss=8.565605
# 2026-04-21,05:06:10 | INFO |   Batch 3400 / 5959: loss=0.576561 cross_entropy_loss=9.058817
# 2026-04-21,05:06:11 | INFO |   Batch 3600 / 5959: loss=0.945900 cross_entropy_loss=9.338698
# 2026-04-21,05:06:13 | INFO |   Batch 3800 / 5959: loss=0.449717 cross_entropy_loss=8.830420
# 2026-04-21,05:06:15 | INFO |   Batch 4000 / 5959: loss=1.136765 cross_entropy_loss=8.533267
# 2026-04-21,05:06:16 | INFO |   Batch 4200 / 5959: loss=1.254686 cross_entropy_loss=9.315985
# 2026-04-21,05:06:18 | INFO |   Batch 4400 / 5959: loss=1.129720 cross_entropy_loss=8.840437
# 2026-04-21,05:06:20 | INFO |   Batch 4600 / 5959: loss=0.960075 cross_entropy_loss=9.253767
# 2026-04-21,05:06:22 | INFO |   Batch 4800 / 5959: loss=0.922833 cross_entropy_loss=9.791515
# 2026-04-21,05:06:23 | INFO |   Batch 5000 / 5959: loss=0.692209 cross_entropy_loss=8.960907
# 2026-04-21,05:06:25 | INFO |   Batch 5200 / 5959: loss=0.645443 cross_entropy_loss=9.666304
# 2026-04-21,05:06:27 | INFO |   Batch 5400 / 5959: loss=0.858751 cross_entropy_loss=8.918821
# 2026-04-21,05:06:28 | INFO |   Batch 5600 / 5959: loss=0.755865 cross_entropy_loss=8.386085
# 2026-04-21,05:06:30 | INFO |   Batch 5800 / 5959: loss=0.978830 cross_entropy_loss=8.827835
# 2026-04-21,05:06:32 | INFO | Evaluating on validation set
# 2026-04-21,05:06:32 | INFO |   Batch 0 / 745: loss=9.357542
# 2026-04-21,05:06:32 | INFO |   Batch 200 / 745: loss=9.359019
# 2026-04-21,05:06:32 | INFO |   Batch 400 / 745: loss=9.703238
# 2026-04-21,05:06:33 | INFO |   Batch 600 / 745: loss=9.203365
# 2026-04-21,05:06:33 | INFO | exp4_cfg07_scent_warmup_tis_k64_t1p0 | epoch=16 train_ce=9.002004 val_loss=9.452818 val_acc=0.137594 best_val_acc=0.137762 best_test_acc=0.000000
# 2026-04-21,05:06:33 | INFO | exp4_cfg07_scent_warmup_tis_k64_t1p0 | Epoch 17/20, learning_rate=0.000134
# 2026-04-21,05:06:34 | INFO |   Batch 0 / 5959: loss=0.612889 cross_entropy_loss=8.882443
# 2026-04-21,05:06:35 | INFO |   Batch 200 / 5959: loss=0.416946 cross_entropy_loss=9.049988
# 2026-04-21,05:06:37 | INFO |   Batch 400 / 5959: loss=0.714381 cross_entropy_loss=9.054354
# 2026-04-21,05:06:39 | INFO |   Batch 600 / 5959: loss=0.678751 cross_entropy_loss=9.197603
# 2026-04-21,05:06:40 | INFO |   Batch 800 / 5959: loss=0.783549 cross_entropy_loss=8.522417
# 2026-04-21,05:06:42 | INFO |   Batch 1000 / 5959: loss=0.668384 cross_entropy_loss=9.202070
# 2026-04-21,05:06:44 | INFO |   Batch 1200 / 5959: loss=1.336314 cross_entropy_loss=9.173570
# 2026-04-21,05:06:46 | INFO |   Batch 1400 / 5959: loss=0.590403 cross_entropy_loss=9.042899
# 2026-04-21,05:06:47 | INFO |   Batch 1600 / 5959: loss=0.385466 cross_entropy_loss=8.655808
# 2026-04-21,05:06:49 | INFO |   Batch 1800 / 5959: loss=0.600166 cross_entropy_loss=8.198322
# 2026-04-21,05:06:51 | INFO |   Batch 2000 / 5959: loss=0.377950 cross_entropy_loss=8.858517
# 2026-04-21,05:06:52 | INFO |   Batch 2200 / 5959: loss=0.935419 cross_entropy_loss=8.430305
# 2026-04-21,05:06:54 | INFO |   Batch 2400 / 5959: loss=1.860756 cross_entropy_loss=8.954802
# 2026-04-21,05:06:56 | INFO |   Batch 2600 / 5959: loss=0.608208 cross_entropy_loss=8.694652
# 2026-04-21,05:06:58 | INFO |   Batch 2800 / 5959: loss=1.785086 cross_entropy_loss=9.349512
# 2026-04-21,05:06:59 | INFO |   Batch 3000 / 5959: loss=0.579680 cross_entropy_loss=9.248200
# 2026-04-21,05:07:01 | INFO |   Batch 3200 / 5959: loss=1.274580 cross_entropy_loss=9.158393
# 2026-04-21,05:07:03 | INFO |   Batch 3400 / 5959: loss=0.879057 cross_entropy_loss=8.612948
# 2026-04-21,05:07:04 | INFO |   Batch 3600 / 5959: loss=0.595364 cross_entropy_loss=9.362623
# 2026-04-21,05:07:06 | INFO |   Batch 3800 / 5959: loss=1.017419 cross_entropy_loss=8.896872
# 2026-04-21,05:07:08 | INFO |   Batch 4000 / 5959: loss=1.638996 cross_entropy_loss=8.941707
# 2026-04-21,05:07:10 | INFO |   Batch 4200 / 5959: loss=0.946313 cross_entropy_loss=8.819393
# 2026-04-21,05:07:11 | INFO |   Batch 4400 / 5959: loss=1.419845 cross_entropy_loss=8.826284
# 2026-04-21,05:07:13 | INFO |   Batch 4600 / 5959: loss=1.081289 cross_entropy_loss=8.819309
# 2026-04-21,05:07:15 | INFO |   Batch 4800 / 5959: loss=0.994855 cross_entropy_loss=8.803646
# 2026-04-21,05:07:16 | INFO |   Batch 5000 / 5959: loss=1.361426 cross_entropy_loss=8.399649
# 2026-04-21,05:07:18 | INFO |   Batch 5200 / 5959: loss=1.075030 cross_entropy_loss=8.297646
# 2026-04-21,05:07:20 | INFO |   Batch 5400 / 5959: loss=0.400711 cross_entropy_loss=9.044449
# 2026-04-21,05:07:22 | INFO |   Batch 5600 / 5959: loss=0.734409 cross_entropy_loss=8.752825
# 2026-04-21,05:07:23 | INFO |   Batch 5800 / 5959: loss=1.849199 cross_entropy_loss=9.080591
# 2026-04-21,05:07:25 | INFO | Evaluating on validation set
# 2026-04-21,05:07:25 | INFO |   Batch 0 / 745: loss=9.372463
# 2026-04-21,05:07:25 | INFO |   Batch 200 / 745: loss=9.373823
# 2026-04-21,05:07:26 | INFO |   Batch 400 / 745: loss=9.720800
# 2026-04-21,05:07:26 | INFO |   Batch 600 / 745: loss=9.220432
# 2026-04-21,05:07:26 | INFO | exp4_cfg07_scent_warmup_tis_k64_t1p0 | epoch=17 train_ce=9.012298 val_loss=9.466656 val_acc=0.137542 best_val_acc=0.137762 best_test_acc=0.000000
# 2026-04-21,05:07:27 | INFO | exp4_cfg07_scent_warmup_tis_k64_t1p0 | Epoch 18/20, learning_rate=0.000060
# 2026-04-21,05:07:27 | INFO |   Batch 0 / 5959: loss=1.009613 cross_entropy_loss=8.952130
# 2026-04-21,05:07:29 | INFO |   Batch 200 / 5959: loss=1.044795 cross_entropy_loss=9.317017
# 2026-04-21,05:07:30 | INFO |   Batch 400 / 5959: loss=1.036999 cross_entropy_loss=8.769738
# 2026-04-21,05:07:32 | INFO |   Batch 600 / 5959: loss=0.765118 cross_entropy_loss=9.743612
# 2026-04-21,05:07:34 | INFO |   Batch 800 / 5959: loss=1.818733 cross_entropy_loss=9.437351
# 2026-04-21,05:07:35 | INFO |   Batch 1000 / 5959: loss=0.586333 cross_entropy_loss=8.943785
# 2026-04-21,05:07:37 | INFO |   Batch 1200 / 5959: loss=0.615518 cross_entropy_loss=8.712419
# 2026-04-21,05:07:39 | INFO |   Batch 1400 / 5959: loss=0.778079 cross_entropy_loss=8.675774
# 2026-04-21,05:07:41 | INFO |   Batch 1600 / 5959: loss=1.106136 cross_entropy_loss=9.284761
# 2026-04-21,05:07:42 | INFO |   Batch 1800 / 5959: loss=1.393344 cross_entropy_loss=9.132761
# 2026-04-21,05:07:44 | INFO |   Batch 2000 / 5959: loss=0.600259 cross_entropy_loss=8.716076
# 2026-04-21,05:07:46 | INFO |   Batch 2200 / 5959: loss=1.439248 cross_entropy_loss=8.564190
# 2026-04-21,05:07:47 | INFO |   Batch 2400 / 5959: loss=1.018389 cross_entropy_loss=9.279814
# 2026-04-21,05:07:49 | INFO |   Batch 2600 / 5959: loss=0.268275 cross_entropy_loss=8.852917
# 2026-04-21,05:07:51 | INFO |   Batch 2800 / 5959: loss=0.364601 cross_entropy_loss=9.053173
# 2026-04-21,05:07:53 | INFO |   Batch 3000 / 5959: loss=0.902289 cross_entropy_loss=8.717833
# 2026-04-21,05:07:54 | INFO |   Batch 3200 / 5959: loss=1.170102 cross_entropy_loss=9.055006
# 2026-04-21,05:07:56 | INFO |   Batch 3400 / 5959: loss=1.307611 cross_entropy_loss=9.054010
# 2026-04-21,05:07:58 | INFO |   Batch 3600 / 5959: loss=0.969047 cross_entropy_loss=9.013498
# 2026-04-21,05:07:59 | INFO |   Batch 3800 / 5959: loss=1.052001 cross_entropy_loss=9.050124
# 2026-04-21,05:08:01 | INFO |   Batch 4000 / 5959: loss=0.512459 cross_entropy_loss=8.874462
# 2026-04-21,05:08:03 | INFO |   Batch 4200 / 5959: loss=0.572374 cross_entropy_loss=9.564469
# 2026-04-21,05:08:05 | INFO |   Batch 4400 / 5959: loss=0.432095 cross_entropy_loss=8.744070
# 2026-04-21,05:08:06 | INFO |   Batch 4600 / 5959: loss=0.671981 cross_entropy_loss=8.489086
# 2026-04-21,05:08:08 | INFO |   Batch 4800 / 5959: loss=0.378326 cross_entropy_loss=9.278031
# 2026-04-21,05:08:10 | INFO |   Batch 5000 / 5959: loss=0.778005 cross_entropy_loss=9.370339
# 2026-04-21,05:08:11 | INFO |   Batch 5200 / 5959: loss=0.728614 cross_entropy_loss=8.339003
# 2026-04-21,05:08:13 | INFO |   Batch 5400 / 5959: loss=0.355457 cross_entropy_loss=9.017056
# 2026-04-21,05:08:15 | INFO |   Batch 5600 / 5959: loss=0.632784 cross_entropy_loss=8.638305
# 2026-04-21,05:08:17 | INFO |   Batch 5800 / 5959: loss=1.519199 cross_entropy_loss=9.445082
# 2026-04-21,05:08:18 | INFO | Evaluating on validation set
# 2026-04-21,05:08:18 | INFO |   Batch 0 / 745: loss=9.380900
# 2026-04-21,05:08:18 | INFO |   Batch 200 / 745: loss=9.382252
# 2026-04-21,05:08:19 | INFO |   Batch 400 / 745: loss=9.730381
# 2026-04-21,05:08:19 | INFO |   Batch 600 / 745: loss=9.229865
# 2026-04-21,05:08:19 | INFO | exp4_cfg07_scent_warmup_tis_k64_t1p0 | epoch=18 train_ce=9.020356 val_loss=9.474467 val_acc=0.137510 best_val_acc=0.137762 best_test_acc=0.000000
# 2026-04-21,05:08:20 | INFO | exp4_cfg07_scent_warmup_tis_k64_t1p0 | Epoch 19/20, learning_rate=0.000015
# 2026-04-21,05:08:20 | INFO |   Batch 0 / 5959: loss=0.551575 cross_entropy_loss=8.827479
# 2026-04-21,05:08:22 | INFO |   Batch 200 / 5959: loss=0.694807 cross_entropy_loss=9.265971
# 2026-04-21,05:08:24 | INFO |   Batch 400 / 5959: loss=1.446207 cross_entropy_loss=9.412493
# 2026-04-21,05:08:25 | INFO |   Batch 600 / 5959: loss=0.828095 cross_entropy_loss=9.412509
# 2026-04-21,05:08:27 | INFO |   Batch 800 / 5959: loss=0.834556 cross_entropy_loss=9.585769
# 2026-04-21,05:08:29 | INFO |   Batch 1000 / 5959: loss=0.457782 cross_entropy_loss=8.881648
# 2026-04-21,05:08:30 | INFO |   Batch 1200 / 5959: loss=1.802309 cross_entropy_loss=8.902897
# 2026-04-21,05:08:32 | INFO |   Batch 1400 / 5959: loss=1.277534 cross_entropy_loss=8.981970
# 2026-04-21,05:08:34 | INFO |   Batch 1600 / 5959: loss=0.931398 cross_entropy_loss=8.826452
# 2026-04-21,05:08:36 | INFO |   Batch 1800 / 5959: loss=0.400556 cross_entropy_loss=8.634487
# 2026-04-21,05:08:37 | INFO |   Batch 2000 / 5959: loss=0.616141 cross_entropy_loss=9.234755
# 2026-04-21,05:08:39 | INFO |   Batch 2200 / 5959: loss=0.389983 cross_entropy_loss=8.814651
# 2026-04-21,05:08:41 | INFO |   Batch 2400 / 5959: loss=1.398570 cross_entropy_loss=9.138981
# 2026-04-21,05:08:42 | INFO |   Batch 2600 / 5959: loss=1.381140 cross_entropy_loss=8.618876
# 2026-04-21,05:08:44 | INFO |   Batch 2800 / 5959: loss=1.205409 cross_entropy_loss=8.797134
# 2026-04-21,05:08:46 | INFO |   Batch 3000 / 5959: loss=1.819091 cross_entropy_loss=8.969187
# 2026-04-21,05:08:48 | INFO |   Batch 3200 / 5959: loss=0.515585 cross_entropy_loss=9.316633
# 2026-04-21,05:08:49 | INFO |   Batch 3400 / 5959: loss=0.541326 cross_entropy_loss=9.417991
# 2026-04-21,05:08:51 | INFO |   Batch 3600 / 5959: loss=0.932132 cross_entropy_loss=9.297350
# 2026-04-21,05:08:53 | INFO |   Batch 3800 / 5959: loss=0.833625 cross_entropy_loss=8.883048
# 2026-04-21,05:08:54 | INFO |   Batch 4000 / 5959: loss=0.316555 cross_entropy_loss=9.134688
# 2026-04-21,05:08:56 | INFO |   Batch 4200 / 5959: loss=0.720083 cross_entropy_loss=8.827383
# 2026-04-21,05:08:58 | INFO |   Batch 4400 / 5959: loss=0.457891 cross_entropy_loss=8.951943
# 2026-04-21,05:09:00 | INFO |   Batch 4600 / 5959: loss=0.574094 cross_entropy_loss=8.680045
# 2026-04-21,05:09:01 | INFO |   Batch 4800 / 5959: loss=1.130860 cross_entropy_loss=8.593585
# 2026-04-21,05:09:03 | INFO |   Batch 5000 / 5959: loss=0.666584 cross_entropy_loss=9.319147
# 2026-04-21,05:09:05 | INFO |   Batch 5200 / 5959: loss=0.609864 cross_entropy_loss=8.966145
# 2026-04-21,05:09:06 | INFO |   Batch 5400 / 5959: loss=1.212168 cross_entropy_loss=9.325084
# 2026-04-21,05:09:08 | INFO |   Batch 5600 / 5959: loss=0.384673 cross_entropy_loss=8.857712
# 2026-04-21,05:09:10 | INFO |   Batch 5800 / 5959: loss=0.421410 cross_entropy_loss=8.594809
# 2026-04-21,05:09:11 | INFO | Evaluating on validation set
# 2026-04-21,05:09:11 | INFO |   Batch 0 / 745: loss=9.383387
# 2026-04-21,05:09:12 | INFO |   Batch 200 / 745: loss=9.384802
# 2026-04-21,05:09:12 | INFO |   Batch 400 / 745: loss=9.733232
# 2026-04-21,05:09:12 | INFO |   Batch 600 / 745: loss=9.232650
# 2026-04-21,05:09:13 | INFO | exp4_cfg07_scent_warmup_tis_k64_t1p0 | epoch=19 train_ce=9.024369 val_loss=9.476779 val_acc=0.137500 best_val_acc=0.137762 best_test_acc=0.000000
# 2026-04-21,05:09:13 | INFO | exp4_cfg07_scent_warmup_tis_k64_t1p0 | Epoch 20/20, learning_rate=0.000000
# 2026-04-21,05:09:13 | INFO |   Batch 0 / 5959: loss=0.707008 cross_entropy_loss=8.814578
# 2026-04-21,05:09:15 | INFO |   Batch 200 / 5959: loss=1.133509 cross_entropy_loss=8.656959
# 2026-04-21,05:09:17 | INFO |   Batch 400 / 5959: loss=1.855816 cross_entropy_loss=8.586774
# 2026-04-21,05:09:18 | INFO |   Batch 600 / 5959: loss=1.445812 cross_entropy_loss=9.053523
# 2026-04-21,05:09:20 | INFO |   Batch 800 / 5959: loss=1.701015 cross_entropy_loss=8.803336
# 2026-04-21,05:09:22 | INFO |   Batch 1000 / 5959: loss=1.675577 cross_entropy_loss=9.111839
# 2026-04-21,05:09:24 | INFO |   Batch 1200 / 5959: loss=0.483339 cross_entropy_loss=8.922113
# 2026-04-21,05:09:25 | INFO |   Batch 1400 / 5959: loss=1.128202 cross_entropy_loss=8.461411
# 2026-04-21,05:09:27 | INFO |   Batch 1600 / 5959: loss=0.538661 cross_entropy_loss=9.566305
# 2026-04-21,05:09:29 | INFO |   Batch 1800 / 5959: loss=0.739535 cross_entropy_loss=9.262442
# 2026-04-21,05:09:30 | INFO |   Batch 2000 / 5959: loss=0.902937 cross_entropy_loss=8.671098
# 2026-04-21,05:09:32 | INFO |   Batch 2200 / 5959: loss=0.453602 cross_entropy_loss=8.757998
# 2026-04-21,05:09:34 | INFO |   Batch 2400 / 5959: loss=0.342050 cross_entropy_loss=8.400278
# 2026-04-21,05:09:36 | INFO |   Batch 2600 / 5959: loss=0.310160 cross_entropy_loss=9.812117
# 2026-04-21,05:09:37 | INFO |   Batch 2800 / 5959: loss=0.453470 cross_entropy_loss=9.232283
# 2026-04-21,05:09:39 | INFO |   Batch 3000 / 5959: loss=0.449277 cross_entropy_loss=8.714488
# 2026-04-21,05:09:41 | INFO |   Batch 3200 / 5959: loss=0.373518 cross_entropy_loss=8.551887
# 2026-04-21,05:09:43 | INFO |   Batch 3400 / 5959: loss=0.630338 cross_entropy_loss=9.049557
# 2026-04-21,05:09:44 | INFO |   Batch 3600 / 5959: loss=1.377908 cross_entropy_loss=9.517691
# 2026-04-21,05:09:46 | INFO |   Batch 3800 / 5959: loss=0.578988 cross_entropy_loss=9.074555
# 2026-04-21,05:09:48 | INFO |   Batch 4000 / 5959: loss=0.399019 cross_entropy_loss=9.424000
# 2026-04-21,05:09:49 | INFO |   Batch 4200 / 5959: loss=1.556659 cross_entropy_loss=8.902301
# 2026-04-21,05:09:51 | INFO |   Batch 4400 / 5959: loss=0.301339 cross_entropy_loss=8.480600
# 2026-04-21,05:09:53 | INFO |   Batch 4600 / 5959: loss=0.320691 cross_entropy_loss=9.041142
# 2026-04-21,05:09:55 | INFO |   Batch 4800 / 5959: loss=0.776048 cross_entropy_loss=8.816492
# 2026-04-21,05:09:56 | INFO |   Batch 5000 / 5959: loss=0.330551 cross_entropy_loss=8.735530
# 2026-04-21,05:09:58 | INFO |   Batch 5200 / 5959: loss=0.817957 cross_entropy_loss=9.213301
# 2026-04-21,05:10:00 | INFO |   Batch 5400 / 5959: loss=0.740161 cross_entropy_loss=9.481182
# 2026-04-21,05:10:01 | INFO |   Batch 5600 / 5959: loss=0.400351 cross_entropy_loss=9.446280
# 2026-04-21,05:10:03 | INFO |   Batch 5800 / 5959: loss=0.369387 cross_entropy_loss=8.910378
# 2026-04-21,05:10:05 | INFO | Evaluating on validation set
# 2026-04-21,05:10:05 | INFO |   Batch 0 / 745: loss=9.383387
# 2026-04-21,05:10:05 | INFO |   Batch 200 / 745: loss=9.384802
# 2026-04-21,05:10:05 | INFO |   Batch 400 / 745: loss=9.733232
# 2026-04-21,05:10:06 | INFO |   Batch 600 / 745: loss=9.232650
# 2026-04-21,05:10:06 | INFO | exp4_cfg07_scent_warmup_tis_k64_t1p0 | epoch=20 train_ce=9.025329 val_loss=9.476779 val_acc=0.137500 best_val_acc=0.137762 best_test_acc=0.000000

# %%
run_experiment(EXPERIMENTS[2])
# Out:
# 2026-04-21,14:05:19 | INFO | Set random seed to 2026
# 2026-04-21,14:05:25 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 1/20, learning_rate=0.001988
# 2026-04-21,14:05:25 | INFO |   Batch 0 / 5959: loss=1.000000 cross_entropy_loss=12.003008
# 2026-04-21,14:05:27 | INFO |   Batch 200 / 5959: loss=1.000000 cross_entropy_loss=11.985525
# 2026-04-21,14:05:29 | INFO |   Batch 400 / 5959: loss=1.000000 cross_entropy_loss=11.963276
# 2026-04-21,14:05:31 | INFO |   Batch 600 / 5959: loss=1.000000 cross_entropy_loss=11.912210
# 2026-04-21,14:05:32 | INFO |   Batch 800 / 5959: loss=1.000000 cross_entropy_loss=11.907568
# 2026-04-21,14:05:34 | INFO |   Batch 1000 / 5959: loss=1.000000 cross_entropy_loss=11.794418
# 2026-04-21,14:05:36 | INFO |   Batch 1200 / 5959: loss=1.000000 cross_entropy_loss=11.791787
# 2026-04-21,14:05:38 | INFO |   Batch 1400 / 5959: loss=1.000000 cross_entropy_loss=11.816587
# 2026-04-21,14:05:40 | INFO |   Batch 1600 / 5959: loss=1.000000 cross_entropy_loss=11.610479
# 2026-04-21,14:05:42 | INFO |   Batch 1800 / 5959: loss=1.000000 cross_entropy_loss=11.666493
# 2026-04-21,14:05:44 | INFO |   Batch 2000 / 5959: loss=1.000000 cross_entropy_loss=11.627460
# 2026-04-21,14:05:46 | INFO |   Batch 2200 / 5959: loss=1.000000 cross_entropy_loss=11.652564
# 2026-04-21,14:05:47 | INFO |   Batch 2400 / 5959: loss=1.000000 cross_entropy_loss=11.699876
# 2026-04-21,14:05:49 | INFO |   Batch 2600 / 5959: loss=1.000000 cross_entropy_loss=11.380742
# 2026-04-21,14:05:51 | INFO |   Batch 2800 / 5959: loss=1.000000 cross_entropy_loss=11.565549
# 2026-04-21,14:05:53 | INFO |   Batch 3000 / 5959: loss=1.000000 cross_entropy_loss=11.656077
# 2026-04-21,14:05:55 | INFO |   Batch 3200 / 5959: loss=1.000000 cross_entropy_loss=11.560162
# 2026-04-21,14:05:57 | INFO |   Batch 3400 / 5959: loss=1.000000 cross_entropy_loss=11.440735
# 2026-04-21,14:05:59 | INFO |   Batch 3600 / 5959: loss=1.000000 cross_entropy_loss=11.400429
# 2026-04-21,14:06:01 | INFO |   Batch 3800 / 5959: loss=1.000000 cross_entropy_loss=11.232678
# 2026-04-21,14:06:03 | INFO |   Batch 4000 / 5959: loss=1.000000 cross_entropy_loss=11.488537
# 2026-04-21,14:06:04 | INFO |   Batch 4200 / 5959: loss=1.000000 cross_entropy_loss=11.166858
# 2026-04-21,14:06:06 | INFO |   Batch 4400 / 5959: loss=1.000000 cross_entropy_loss=11.322191
# 2026-04-21,14:06:08 | INFO |   Batch 4600 / 5959: loss=1.000000 cross_entropy_loss=11.214777
# 2026-04-21,14:06:10 | INFO |   Batch 4800 / 5959: loss=1.000000 cross_entropy_loss=11.201442
# 2026-04-21,14:06:12 | INFO |   Batch 5000 / 5959: loss=1.000000 cross_entropy_loss=11.508272
# 2026-04-21,14:06:14 | INFO |   Batch 5200 / 5959: loss=1.000000 cross_entropy_loss=11.351995
# 2026-04-21,14:06:16 | INFO |   Batch 5400 / 5959: loss=1.000000 cross_entropy_loss=10.739887
# 2026-04-21,14:06:18 | INFO |   Batch 5600 / 5959: loss=1.000000 cross_entropy_loss=11.112436
# 2026-04-21,14:06:19 | INFO |   Batch 5800 / 5959: loss=1.000000 cross_entropy_loss=10.514479
# 2026-04-21,14:06:21 | INFO | Evaluating on validation set
# 2026-04-21,14:06:21 | INFO |   Batch 0 / 745: loss=10.955019
# 2026-04-21,14:06:21 | INFO |   Batch 200 / 745: loss=10.909184
# 2026-04-21,14:06:22 | INFO |   Batch 400 / 745: loss=11.111576
# 2026-04-21,14:06:22 | INFO |   Batch 600 / 745: loss=10.787680
# 2026-04-21,14:06:22 | INFO | exp4_cfg03_scent_tis_proxy | epoch=1 train_ce=11.481356 val_loss=10.949765 val_acc=0.133860 best_val_acc=0.133860 best_test_acc=0.000000
# 2026-04-21,14:06:23 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 2/20, learning_rate=0.001951
# 2026-04-21,14:06:23 | INFO |   Batch 0 / 5959: loss=1.661542 cross_entropy_loss=11.357426
# 2026-04-21,14:06:25 | INFO |   Batch 200 / 5959: loss=1.932864 cross_entropy_loss=11.303692
# 2026-04-21,14:06:27 | INFO |   Batch 400 / 5959: loss=1.592870 cross_entropy_loss=10.610388
# 2026-04-21,14:06:29 | INFO |   Batch 600 / 5959: loss=1.613311 cross_entropy_loss=10.193361
# 2026-04-21,14:06:30 | INFO |   Batch 800 / 5959: loss=1.922940 cross_entropy_loss=10.697254
# 2026-04-21,14:06:32 | INFO |   Batch 1000 / 5959: loss=1.793527 cross_entropy_loss=10.636799
# 2026-04-21,14:06:34 | INFO |   Batch 1200 / 5959: loss=1.909204 cross_entropy_loss=10.598969
# 2026-04-21,14:06:36 | INFO |   Batch 1400 / 5959: loss=1.886897 cross_entropy_loss=10.839401
# 2026-04-21,14:06:38 | INFO |   Batch 1600 / 5959: loss=1.835639 cross_entropy_loss=10.582544
# 2026-04-21,14:06:39 | INFO |   Batch 1800 / 5959: loss=1.929608 cross_entropy_loss=10.530138
# 2026-04-21,14:06:41 | INFO |   Batch 2000 / 5959: loss=1.780265 cross_entropy_loss=10.229229
# 2026-04-21,14:06:43 | INFO |   Batch 2200 / 5959: loss=1.915271 cross_entropy_loss=10.114790
# 2026-04-21,14:06:45 | INFO |   Batch 2400 / 5959: loss=1.843629 cross_entropy_loss=9.716028
# 2026-04-21,14:06:47 | INFO |   Batch 2600 / 5959: loss=1.863170 cross_entropy_loss=10.430772
# 2026-04-21,14:06:48 | INFO |   Batch 2800 / 5959: loss=1.864969 cross_entropy_loss=10.359272
# 2026-04-21,14:06:50 | INFO |   Batch 3000 / 5959: loss=1.848777 cross_entropy_loss=10.082847
# 2026-04-21,14:06:52 | INFO |   Batch 3200 / 5959: loss=1.843354 cross_entropy_loss=10.465324
# 2026-04-21,14:06:54 | INFO |   Batch 3400 / 5959: loss=1.852392 cross_entropy_loss=10.099402
# 2026-04-21,14:06:56 | INFO |   Batch 3600 / 5959: loss=1.847823 cross_entropy_loss=10.702639
# 2026-04-21,14:06:57 | INFO |   Batch 3800 / 5959: loss=1.844337 cross_entropy_loss=10.481628
# 2026-04-21,14:06:59 | INFO |   Batch 4000 / 5959: loss=1.845319 cross_entropy_loss=10.852839
# 2026-04-21,14:07:01 | INFO |   Batch 4200 / 5959: loss=1.786503 cross_entropy_loss=10.605439
# 2026-04-21,14:07:03 | INFO |   Batch 4400 / 5959: loss=1.765638 cross_entropy_loss=10.170525
# 2026-04-21,14:07:05 | INFO |   Batch 4600 / 5959: loss=1.777686 cross_entropy_loss=10.273528
# 2026-04-21,14:07:06 | INFO |   Batch 4800 / 5959: loss=1.810628 cross_entropy_loss=10.851755
# 2026-04-21,14:07:08 | INFO |   Batch 5000 / 5959: loss=1.788560 cross_entropy_loss=10.286583
# 2026-04-21,14:07:10 | INFO |   Batch 5200 / 5959: loss=1.770754 cross_entropy_loss=10.358263
# 2026-04-21,14:07:12 | INFO |   Batch 5400 / 5959: loss=1.810148 cross_entropy_loss=10.584995
# 2026-04-21,14:07:14 | INFO |   Batch 5600 / 5959: loss=1.722988 cross_entropy_loss=10.003781
# 2026-04-21,14:07:15 | INFO |   Batch 5800 / 5959: loss=1.804170 cross_entropy_loss=10.440834
# 2026-04-21,14:07:17 | INFO | Evaluating on validation set
# 2026-04-21,14:07:17 | INFO |   Batch 0 / 745: loss=10.338718
# 2026-04-21,14:07:17 | INFO |   Batch 200 / 745: loss=10.319590
# 2026-04-21,14:07:18 | INFO |   Batch 400 / 745: loss=10.692291
# 2026-04-21,14:07:18 | INFO |   Batch 600 / 745: loss=10.134811
# 2026-04-21,14:07:18 | INFO | exp4_cfg03_scent_tis_proxy | epoch=2 train_ce=10.524013 val_loss=10.412172 val_acc=0.133860 best_val_acc=0.133860 best_test_acc=0.000000
# 2026-04-21,14:07:19 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 3/20, learning_rate=0.001891
# 2026-04-21,14:07:19 | INFO |   Batch 0 / 5959: loss=1.210434 cross_entropy_loss=10.615036
# 2026-04-21,14:07:21 | INFO |   Batch 200 / 5959: loss=1.189848 cross_entropy_loss=10.187755
# 2026-04-21,14:07:23 | INFO |   Batch 400 / 5959: loss=1.221655 cross_entropy_loss=9.830879
# 2026-04-21,14:07:25 | INFO |   Batch 600 / 5959: loss=1.228347 cross_entropy_loss=10.515806
# 2026-04-21,14:07:26 | INFO |   Batch 800 / 5959: loss=1.193072 cross_entropy_loss=10.145931
# 2026-04-21,14:07:28 | INFO |   Batch 1000 / 5959: loss=1.226784 cross_entropy_loss=10.290741
# 2026-04-21,14:07:30 | INFO |   Batch 1200 / 5959: loss=1.223048 cross_entropy_loss=10.049048
# 2026-04-21,14:07:32 | INFO |   Batch 1400 / 5959: loss=1.219497 cross_entropy_loss=10.488033
# 2026-04-21,14:07:33 | INFO |   Batch 1600 / 5959: loss=1.257631 cross_entropy_loss=10.900355
# 2026-04-21,14:07:35 | INFO |   Batch 1800 / 5959: loss=1.235073 cross_entropy_loss=10.599253
# 2026-04-21,14:07:37 | INFO |   Batch 2000 / 5959: loss=1.216318 cross_entropy_loss=10.168726
# 2026-04-21,14:07:39 | INFO |   Batch 2200 / 5959: loss=1.207145 cross_entropy_loss=10.208744
# 2026-04-21,14:07:41 | INFO |   Batch 2400 / 5959: loss=1.163248 cross_entropy_loss=9.513134
# 2026-04-21,14:07:42 | INFO |   Batch 2600 / 5959: loss=1.191990 cross_entropy_loss=10.038769
# 2026-04-21,14:07:44 | INFO |   Batch 2800 / 5959: loss=1.233112 cross_entropy_loss=10.249522
# 2026-04-21,14:07:46 | INFO |   Batch 3000 / 5959: loss=1.156191 cross_entropy_loss=9.752174
# 2026-04-21,14:07:48 | INFO |   Batch 3200 / 5959: loss=1.176347 cross_entropy_loss=10.284359
# 2026-04-21,14:07:50 | INFO |   Batch 3400 / 5959: loss=1.211699 cross_entropy_loss=10.390198
# 2026-04-21,14:07:52 | INFO |   Batch 3600 / 5959: loss=1.247417 cross_entropy_loss=10.895588
# 2026-04-21,14:07:53 | INFO |   Batch 3800 / 5959: loss=1.173916 cross_entropy_loss=10.250879
# 2026-04-21,14:07:55 | INFO |   Batch 4000 / 5959: loss=1.168513 cross_entropy_loss=10.558792
# 2026-04-21,14:07:57 | INFO |   Batch 4200 / 5959: loss=1.187278 cross_entropy_loss=10.255710
# 2026-04-21,14:07:59 | INFO |   Batch 4400 / 5959: loss=1.193259 cross_entropy_loss=10.412696
# 2026-04-21,14:08:01 | INFO |   Batch 4600 / 5959: loss=1.151669 cross_entropy_loss=9.947071
# 2026-04-21,14:08:02 | INFO |   Batch 4800 / 5959: loss=1.144286 cross_entropy_loss=10.558249
# 2026-04-21,14:08:04 | INFO |   Batch 5000 / 5959: loss=1.174308 cross_entropy_loss=10.545746
# 2026-04-21,14:08:06 | INFO |   Batch 5200 / 5959: loss=1.147702 cross_entropy_loss=10.218934
# 2026-04-21,14:08:08 | INFO |   Batch 5400 / 5959: loss=1.157310 cross_entropy_loss=9.830858
# 2026-04-21,14:08:10 | INFO |   Batch 5600 / 5959: loss=1.164804 cross_entropy_loss=10.293028
# 2026-04-21,14:08:11 | INFO |   Batch 5800 / 5959: loss=1.125708 cross_entropy_loss=10.141615
# 2026-04-21,14:08:13 | INFO | Evaluating on validation set
# 2026-04-21,14:08:13 | INFO |   Batch 0 / 745: loss=10.296429
# 2026-04-21,14:08:13 | INFO |   Batch 200 / 745: loss=10.255085
# 2026-04-21,14:08:14 | INFO |   Batch 400 / 745: loss=10.659832
# 2026-04-21,14:08:14 | INFO |   Batch 600 / 745: loss=10.097629
# 2026-04-21,14:08:14 | INFO | exp4_cfg03_scent_tis_proxy | epoch=3 train_ce=10.317736 val_loss=10.359872 val_acc=0.133923 best_val_acc=0.133923 best_test_acc=0.000000
# 2026-04-21,14:08:15 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 4/20, learning_rate=0.001809
# 2026-04-21,14:08:15 | INFO |   Batch 0 / 5959: loss=0.939083 cross_entropy_loss=10.443106
# 2026-04-21,14:08:17 | INFO |   Batch 200 / 5959: loss=0.944918 cross_entropy_loss=10.081812
# 2026-04-21,14:08:19 | INFO |   Batch 400 / 5959: loss=0.958847 cross_entropy_loss=10.840895
# 2026-04-21,14:08:20 | INFO |   Batch 600 / 5959: loss=0.963220 cross_entropy_loss=10.287666
# 2026-04-21,14:08:22 | INFO |   Batch 800 / 5959: loss=0.927356 cross_entropy_loss=9.482698
# 2026-04-21,14:08:24 | INFO |   Batch 1000 / 5959: loss=0.921095 cross_entropy_loss=10.247499
# 2026-04-21,14:08:26 | INFO |   Batch 1200 / 5959: loss=0.904776 cross_entropy_loss=10.151814
# 2026-04-21,14:08:28 | INFO |   Batch 1400 / 5959: loss=0.956735 cross_entropy_loss=10.343177
# 2026-04-21,14:08:29 | INFO |   Batch 1600 / 5959: loss=0.952753 cross_entropy_loss=10.326839
# 2026-04-21,14:08:31 | INFO |   Batch 1800 / 5959: loss=0.927420 cross_entropy_loss=10.210649
# 2026-04-21,14:08:33 | INFO |   Batch 2000 / 5959: loss=0.921727 cross_entropy_loss=10.008099
# 2026-04-21,14:08:35 | INFO |   Batch 2200 / 5959: loss=0.907948 cross_entropy_loss=9.551355
# 2026-04-21,14:08:37 | INFO |   Batch 2400 / 5959: loss=0.936943 cross_entropy_loss=10.686865
# 2026-04-21,14:08:38 | INFO |   Batch 2600 / 5959: loss=0.903700 cross_entropy_loss=10.026981
# 2026-04-21,14:08:40 | INFO |   Batch 2800 / 5959: loss=0.885798 cross_entropy_loss=9.744394
# 2026-04-21,14:08:42 | INFO |   Batch 3000 / 5959: loss=0.911873 cross_entropy_loss=9.882835
# 2026-04-21,14:08:44 | INFO |   Batch 3200 / 5959: loss=0.907701 cross_entropy_loss=9.776965
# 2026-04-21,14:08:46 | INFO |   Batch 3400 / 5959: loss=0.921169 cross_entropy_loss=10.306345
# 2026-04-21,14:08:47 | INFO |   Batch 3600 / 5959: loss=0.881907 cross_entropy_loss=9.309383
# 2026-04-21,14:08:49 | INFO |   Batch 3800 / 5959: loss=0.914210 cross_entropy_loss=10.484509
# 2026-04-21,14:08:51 | INFO |   Batch 4000 / 5959: loss=0.907701 cross_entropy_loss=10.318379
# 2026-04-21,14:08:53 | INFO |   Batch 4200 / 5959: loss=0.905907 cross_entropy_loss=10.168877
# 2026-04-21,14:08:55 | INFO |   Batch 4400 / 5959: loss=0.907269 cross_entropy_loss=9.916695
# 2026-04-21,14:08:56 | INFO |   Batch 4600 / 5959: loss=0.872745 cross_entropy_loss=10.248260
# 2026-04-21,14:08:58 | INFO |   Batch 4800 / 5959: loss=0.926312 cross_entropy_loss=10.391563
# 2026-04-21,14:09:00 | INFO |   Batch 5000 / 5959: loss=0.886545 cross_entropy_loss=9.698450
# 2026-04-21,14:09:02 | INFO |   Batch 5200 / 5959: loss=0.851681 cross_entropy_loss=10.531730
# 2026-04-21,14:09:04 | INFO |   Batch 5400 / 5959: loss=0.870275 cross_entropy_loss=10.172548
# 2026-04-21,14:09:05 | INFO |   Batch 5600 / 5959: loss=0.888293 cross_entropy_loss=10.583590
# 2026-04-21,14:09:07 | INFO |   Batch 5800 / 5959: loss=0.903605 cross_entropy_loss=10.772355
# 2026-04-21,14:09:09 | INFO | Evaluating on validation set
# 2026-04-21,14:09:09 | INFO |   Batch 0 / 745: loss=10.287210
# 2026-04-21,14:09:09 | INFO |   Batch 200 / 745: loss=10.255551
# 2026-04-21,14:09:10 | INFO |   Batch 400 / 745: loss=10.651043
# 2026-04-21,14:09:10 | INFO |   Batch 600 / 745: loss=10.112979
# 2026-04-21,14:09:10 | INFO | exp4_cfg03_scent_tis_proxy | epoch=4 train_ce=10.244408 val_loss=10.349754 val_acc=0.133996 best_val_acc=0.133996 best_test_acc=0.000000
# 2026-04-21,14:09:11 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 5/20, learning_rate=0.001707
# 2026-04-21,14:09:11 | INFO |   Batch 0 / 5959: loss=0.839730 cross_entropy_loss=10.002295
# 2026-04-21,14:09:13 | INFO |   Batch 200 / 5959: loss=0.849245 cross_entropy_loss=10.342034
# 2026-04-21,14:09:15 | INFO |   Batch 400 / 5959: loss=0.900074 cross_entropy_loss=10.532784
# 2026-04-21,14:09:16 | INFO |   Batch 600 / 5959: loss=0.878073 cross_entropy_loss=10.059311
# 2026-04-21,14:09:18 | INFO |   Batch 800 / 5959: loss=0.856033 cross_entropy_loss=9.647181
# 2026-04-21,14:09:20 | INFO |   Batch 1000 / 5959: loss=0.912958 cross_entropy_loss=10.715556
# 2026-04-21,14:09:22 | INFO |   Batch 1200 / 5959: loss=0.860815 cross_entropy_loss=10.268030
# 2026-04-21,14:09:24 | INFO |   Batch 1400 / 5959: loss=0.849576 cross_entropy_loss=10.049455
# 2026-04-21,14:09:25 | INFO |   Batch 1600 / 5959: loss=0.841115 cross_entropy_loss=9.999638
# 2026-04-21,14:09:27 | INFO |   Batch 1800 / 5959: loss=0.839268 cross_entropy_loss=9.837395
# 2026-04-21,14:09:29 | INFO |   Batch 2000 / 5959: loss=0.894862 cross_entropy_loss=10.881932
# 2026-04-21,14:09:31 | INFO |   Batch 2200 / 5959: loss=0.816703 cross_entropy_loss=9.582609
# 2026-04-21,14:09:33 | INFO |   Batch 2400 / 5959: loss=0.881009 cross_entropy_loss=10.638102
# 2026-04-21,14:09:34 | INFO |   Batch 2600 / 5959: loss=0.811310 cross_entropy_loss=9.596126
# 2026-04-21,14:09:36 | INFO |   Batch 2800 / 5959: loss=0.810241 cross_entropy_loss=9.737459
# 2026-04-21,14:09:38 | INFO |   Batch 3000 / 5959: loss=0.833400 cross_entropy_loss=10.278811
# 2026-04-21,14:09:40 | INFO |   Batch 3200 / 5959: loss=0.815250 cross_entropy_loss=9.961870
# 2026-04-21,14:09:42 | INFO |   Batch 3400 / 5959: loss=0.806099 cross_entropy_loss=9.522684
# 2026-04-21,14:09:43 | INFO |   Batch 3600 / 5959: loss=0.821139 cross_entropy_loss=10.449549
# 2026-04-21,14:09:45 | INFO |   Batch 3800 / 5959: loss=0.848780 cross_entropy_loss=10.560240
# 2026-04-21,14:09:47 | INFO |   Batch 4000 / 5959: loss=0.828675 cross_entropy_loss=10.641233
# 2026-04-21,14:09:49 | INFO |   Batch 4200 / 5959: loss=0.845715 cross_entropy_loss=10.658917
# 2026-04-21,14:09:51 | INFO |   Batch 4400 / 5959: loss=0.839312 cross_entropy_loss=10.597345
# 2026-04-21,14:09:52 | INFO |   Batch 4600 / 5959: loss=0.851969 cross_entropy_loss=10.538673
# 2026-04-21,14:09:54 | INFO |   Batch 4800 / 5959: loss=0.801398 cross_entropy_loss=10.320696
# 2026-04-21,14:09:56 | INFO |   Batch 5000 / 5959: loss=0.779621 cross_entropy_loss=9.968175
# 2026-04-21,14:09:58 | INFO |   Batch 5200 / 5959: loss=0.815134 cross_entropy_loss=9.710878
# 2026-04-21,14:10:00 | INFO |   Batch 5400 / 5959: loss=0.825565 cross_entropy_loss=10.329947
# 2026-04-21,14:10:01 | INFO |   Batch 5600 / 5959: loss=0.837991 cross_entropy_loss=10.285852
# 2026-04-21,14:10:03 | INFO |   Batch 5800 / 5959: loss=0.808556 cross_entropy_loss=10.385914
# 2026-04-21,14:10:05 | INFO | Evaluating on validation set
# 2026-04-21,14:10:05 | INFO |   Batch 0 / 745: loss=10.308042
# 2026-04-21,14:10:05 | INFO |   Batch 200 / 745: loss=10.282650
# 2026-04-21,14:10:05 | INFO |   Batch 400 / 745: loss=10.678909
# 2026-04-21,14:10:06 | INFO |   Batch 600 / 745: loss=10.146843
# 2026-04-21,14:10:06 | INFO | exp4_cfg03_scent_tis_proxy | epoch=5 train_ce=10.209347 val_loss=10.366185 val_acc=0.134070 best_val_acc=0.134070 best_test_acc=0.000000
# 2026-04-21,14:10:07 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 6/20, learning_rate=0.001588
# 2026-04-21,14:10:07 | INFO |   Batch 0 / 5959: loss=0.824213 cross_entropy_loss=9.912125
# 2026-04-21,14:10:09 | INFO |   Batch 200 / 5959: loss=0.842506 cross_entropy_loss=10.228512
# 2026-04-21,14:10:10 | INFO |   Batch 400 / 5959: loss=0.851618 cross_entropy_loss=10.382719
# 2026-04-21,14:10:12 | INFO |   Batch 600 / 5959: loss=0.828432 cross_entropy_loss=9.767160
# 2026-04-21,14:10:14 | INFO |   Batch 800 / 5959: loss=0.843254 cross_entropy_loss=10.231846
# 2026-04-21,14:10:16 | INFO |   Batch 1000 / 5959: loss=0.844976 cross_entropy_loss=10.231885
# 2026-04-21,14:10:18 | INFO |   Batch 1200 / 5959: loss=0.864167 cross_entropy_loss=9.822124
# 2026-04-21,14:10:19 | INFO |   Batch 1400 / 5959: loss=0.851740 cross_entropy_loss=10.629127
# 2026-04-21,14:10:21 | INFO |   Batch 1600 / 5959: loss=0.837309 cross_entropy_loss=10.360580
# 2026-04-21,14:10:23 | INFO |   Batch 1800 / 5959: loss=0.813957 cross_entropy_loss=9.862807
# 2026-04-21,14:10:25 | INFO |   Batch 2000 / 5959: loss=0.800630 cross_entropy_loss=9.804443
# 2026-04-21,14:10:27 | INFO |   Batch 2200 / 5959: loss=0.816843 cross_entropy_loss=10.473566
# 2026-04-21,14:10:28 | INFO |   Batch 2400 / 5959: loss=0.827085 cross_entropy_loss=10.784883
# 2026-04-21,14:10:30 | INFO |   Batch 2600 / 5959: loss=0.833222 cross_entropy_loss=10.135098
# 2026-04-21,14:10:32 | INFO |   Batch 2800 / 5959: loss=0.799395 cross_entropy_loss=9.878632
# 2026-04-21,14:10:34 | INFO |   Batch 3000 / 5959: loss=0.802158 cross_entropy_loss=10.214985
# 2026-04-21,14:10:36 | INFO |   Batch 3200 / 5959: loss=0.789206 cross_entropy_loss=9.825884
# 2026-04-21,14:10:37 | INFO |   Batch 3400 / 5959: loss=0.826402 cross_entropy_loss=10.635725
# 2026-04-21,14:10:39 | INFO |   Batch 3600 / 5959: loss=0.764383 cross_entropy_loss=9.953344
# 2026-04-21,14:10:41 | INFO |   Batch 3800 / 5959: loss=0.818289 cross_entropy_loss=10.851427
# 2026-04-21,14:10:43 | INFO |   Batch 4000 / 5959: loss=0.810486 cross_entropy_loss=10.245485
# 2026-04-21,14:10:45 | INFO |   Batch 4200 / 5959: loss=0.782715 cross_entropy_loss=9.924447
# 2026-04-21,14:10:46 | INFO |   Batch 4400 / 5959: loss=0.819696 cross_entropy_loss=10.206104
# 2026-04-21,14:10:48 | INFO |   Batch 4600 / 5959: loss=0.788024 cross_entropy_loss=10.298249
# 2026-04-21,14:10:50 | INFO |   Batch 4800 / 5959: loss=0.810273 cross_entropy_loss=10.485188
# 2026-04-21,14:10:52 | INFO |   Batch 5000 / 5959: loss=0.803010 cross_entropy_loss=10.039370
# 2026-04-21,14:10:54 | INFO |   Batch 5200 / 5959: loss=0.832242 cross_entropy_loss=10.356925
# 2026-04-21,14:10:55 | INFO |   Batch 5400 / 5959: loss=0.794731 cross_entropy_loss=10.237612
# 2026-04-21,14:10:57 | INFO |   Batch 5600 / 5959: loss=0.807378 cross_entropy_loss=10.152371
# 2026-04-21,14:10:59 | INFO |   Batch 5800 / 5959: loss=0.764443 cross_entropy_loss=10.106217
# 2026-04-21,14:11:01 | INFO | Evaluating on validation set
# 2026-04-21,14:11:01 | INFO |   Batch 0 / 745: loss=10.344171
# 2026-04-21,14:11:01 | INFO |   Batch 200 / 745: loss=10.330410
# 2026-04-21,14:11:01 | INFO |   Batch 400 / 745: loss=10.722481
# 2026-04-21,14:11:02 | INFO |   Batch 600 / 745: loss=10.196304
# 2026-04-21,14:11:02 | INFO | exp4_cfg03_scent_tis_proxy | epoch=6 train_ce=10.196922 val_loss=10.399777 val_acc=0.134154 best_val_acc=0.134154 best_test_acc=0.000000
# 2026-04-21,14:11:03 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 7/20, learning_rate=0.001454
# 2026-04-21,14:11:03 | INFO |   Batch 0 / 5959: loss=0.834631 cross_entropy_loss=10.608847
# 2026-04-21,14:11:05 | INFO |   Batch 200 / 5959: loss=0.830749 cross_entropy_loss=9.717373
# 2026-04-21,14:11:06 | INFO |   Batch 400 / 5959: loss=0.797115 cross_entropy_loss=9.752195
# 2026-04-21,14:11:08 | INFO |   Batch 600 / 5959: loss=0.851489 cross_entropy_loss=10.093952
# 2026-04-21,14:11:10 | INFO |   Batch 800 / 5959: loss=0.858720 cross_entropy_loss=10.594448
# 2026-04-21,14:11:12 | INFO |   Batch 1000 / 5959: loss=0.800071 cross_entropy_loss=10.243208
# 2026-04-21,14:11:14 | INFO |   Batch 1200 / 5959: loss=0.845515 cross_entropy_loss=10.365463
# 2026-04-21,14:11:15 | INFO |   Batch 1400 / 5959: loss=0.810041 cross_entropy_loss=9.901468
# 2026-04-21,14:11:17 | INFO |   Batch 1600 / 5959: loss=0.814466 cross_entropy_loss=10.349478
# 2026-04-21,14:11:19 | INFO |   Batch 1800 / 5959: loss=0.789355 cross_entropy_loss=9.806587
# 2026-04-21,14:11:21 | INFO |   Batch 2000 / 5959: loss=0.793165 cross_entropy_loss=9.496222
# 2026-04-21,14:11:23 | INFO |   Batch 2200 / 5959: loss=0.803199 cross_entropy_loss=8.823196
# 2026-04-21,14:11:24 | INFO |   Batch 2400 / 5959: loss=0.861596 cross_entropy_loss=10.486742
# 2026-04-21,14:11:26 | INFO |   Batch 2600 / 5959: loss=0.838259 cross_entropy_loss=10.366247
# 2026-04-21,14:11:28 | INFO |   Batch 2800 / 5959: loss=0.876048 cross_entropy_loss=10.737923
# 2026-04-21,14:11:30 | INFO |   Batch 3000 / 5959: loss=0.812984 cross_entropy_loss=10.615134
# 2026-04-21,14:11:32 | INFO |   Batch 3200 / 5959: loss=0.873972 cross_entropy_loss=11.308376
# 2026-04-21,14:11:33 | INFO |   Batch 3400 / 5959: loss=0.817698 cross_entropy_loss=10.883548
# 2026-04-21,14:11:35 | INFO |   Batch 3600 / 5959: loss=0.817184 cross_entropy_loss=10.279094
# 2026-04-21,14:11:37 | INFO |   Batch 3800 / 5959: loss=0.733843 cross_entropy_loss=9.368488
# 2026-04-21,14:11:39 | INFO |   Batch 4000 / 5959: loss=0.784339 cross_entropy_loss=10.182690
# 2026-04-21,14:11:41 | INFO |   Batch 4200 / 5959: loss=0.798341 cross_entropy_loss=10.438906
# 2026-04-21,14:11:42 | INFO |   Batch 4400 / 5959: loss=0.816320 cross_entropy_loss=10.355673
# 2026-04-21,14:11:44 | INFO |   Batch 4600 / 5959: loss=0.806075 cross_entropy_loss=10.246151
# 2026-04-21,14:11:46 | INFO |   Batch 4800 / 5959: loss=0.771114 cross_entropy_loss=10.325060
# 2026-04-21,14:11:48 | INFO |   Batch 5000 / 5959: loss=0.789010 cross_entropy_loss=10.215156
# 2026-04-21,14:11:50 | INFO |   Batch 5200 / 5959: loss=0.790180 cross_entropy_loss=9.818981
# 2026-04-21,14:11:51 | INFO |   Batch 5400 / 5959: loss=0.791184 cross_entropy_loss=10.724997
# 2026-04-21,14:11:53 | INFO |   Batch 5600 / 5959: loss=0.786479 cross_entropy_loss=10.008414
# 2026-04-21,14:11:55 | INFO |   Batch 5800 / 5959: loss=0.780714 cross_entropy_loss=10.184988
# 2026-04-21,14:11:57 | INFO | Evaluating on validation set
# 2026-04-21,14:11:57 | INFO |   Batch 0 / 745: loss=10.390873
# 2026-04-21,14:11:57 | INFO |   Batch 200 / 745: loss=10.388872
# 2026-04-21,14:11:57 | INFO |   Batch 400 / 745: loss=10.779831
# 2026-04-21,14:11:58 | INFO |   Batch 600 / 745: loss=10.248387
# 2026-04-21,14:11:58 | INFO | exp4_cfg03_scent_tis_proxy | epoch=7 train_ce=10.202866 val_loss=10.444431 val_acc=0.134227 best_val_acc=0.134227 best_test_acc=0.000000
# 2026-04-21,14:11:59 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 8/20, learning_rate=0.001309
# 2026-04-21,14:11:59 | INFO |   Batch 0 / 5959: loss=0.832491 cross_entropy_loss=10.335382
# 2026-04-21,14:12:01 | INFO |   Batch 200 / 5959: loss=0.820883 cross_entropy_loss=10.203083
# 2026-04-21,14:12:02 | INFO |   Batch 400 / 5959: loss=0.832459 cross_entropy_loss=10.183917
# 2026-04-21,14:12:04 | INFO |   Batch 600 / 5959: loss=0.794369 cross_entropy_loss=10.191077
# 2026-04-21,14:12:06 | INFO |   Batch 800 / 5959: loss=0.832817 cross_entropy_loss=10.088063
# 2026-04-21,14:12:08 | INFO |   Batch 1000 / 5959: loss=0.858190 cross_entropy_loss=10.614283
# 2026-04-21,14:12:10 | INFO |   Batch 1200 / 5959: loss=0.847238 cross_entropy_loss=10.704702
# 2026-04-21,14:12:11 | INFO |   Batch 1400 / 5959: loss=0.784219 cross_entropy_loss=10.221555
# 2026-04-21,14:12:13 | INFO |   Batch 1600 / 5959: loss=0.830135 cross_entropy_loss=10.261926
# 2026-04-21,14:12:15 | INFO |   Batch 1800 / 5959: loss=0.803899 cross_entropy_loss=9.561106
# 2026-04-21,14:12:17 | INFO |   Batch 2000 / 5959: loss=0.789678 cross_entropy_loss=9.973742
# 2026-04-21,14:12:19 | INFO |   Batch 2200 / 5959: loss=0.840900 cross_entropy_loss=10.021107
# 2026-04-21,14:12:20 | INFO |   Batch 2400 / 5959: loss=0.769189 cross_entropy_loss=10.107296
# 2026-04-21,14:12:22 | INFO |   Batch 2600 / 5959: loss=0.791857 cross_entropy_loss=9.951067
# 2026-04-21,14:12:24 | INFO |   Batch 2800 / 5959: loss=0.797315 cross_entropy_loss=9.610990
# 2026-04-21,14:12:26 | INFO |   Batch 3000 / 5959: loss=0.813708 cross_entropy_loss=10.503664
# 2026-04-21,14:12:28 | INFO |   Batch 3200 / 5959: loss=0.823859 cross_entropy_loss=10.498444
# 2026-04-21,14:12:29 | INFO |   Batch 3400 / 5959: loss=0.817371 cross_entropy_loss=9.929733
# 2026-04-21,14:12:31 | INFO |   Batch 3600 / 5959: loss=0.809112 cross_entropy_loss=10.043407
# 2026-04-21,14:12:33 | INFO |   Batch 3800 / 5959: loss=0.813246 cross_entropy_loss=10.877003
# 2026-04-21,14:12:35 | INFO |   Batch 4000 / 5959: loss=0.818877 cross_entropy_loss=10.624818
# 2026-04-21,14:12:37 | INFO |   Batch 4200 / 5959: loss=0.779557 cross_entropy_loss=10.483324
# 2026-04-21,14:12:38 | INFO |   Batch 4400 / 5959: loss=0.791854 cross_entropy_loss=9.889235
# 2026-04-21,14:12:40 | INFO |   Batch 4600 / 5959: loss=0.747235 cross_entropy_loss=9.896851
# 2026-04-21,14:12:42 | INFO |   Batch 4800 / 5959: loss=0.822074 cross_entropy_loss=10.574865
# 2026-04-21,14:12:44 | INFO |   Batch 5000 / 5959: loss=0.757857 cross_entropy_loss=9.895933
# 2026-04-21,14:12:46 | INFO |   Batch 5200 / 5959: loss=0.782060 cross_entropy_loss=10.193342
# 2026-04-21,14:12:47 | INFO |   Batch 5400 / 5959: loss=0.825173 cross_entropy_loss=10.292762
# 2026-04-21,14:12:49 | INFO |   Batch 5600 / 5959: loss=0.798410 cross_entropy_loss=10.185654
# 2026-04-21,14:12:51 | INFO |   Batch 5800 / 5959: loss=0.809533 cross_entropy_loss=10.021229
# 2026-04-21,14:12:52 | INFO | Evaluating on validation set
# 2026-04-21,14:12:52 | INFO |   Batch 0 / 745: loss=10.443969
# 2026-04-21,14:12:53 | INFO |   Batch 200 / 745: loss=10.451843
# 2026-04-21,14:12:53 | INFO |   Batch 400 / 745: loss=10.842093
# 2026-04-21,14:12:54 | INFO |   Batch 600 / 745: loss=10.312191
# 2026-04-21,14:12:54 | INFO | exp4_cfg03_scent_tis_proxy | epoch=8 train_ce=10.219960 val_loss=10.496268 val_acc=0.134290 best_val_acc=0.134290 best_test_acc=0.000000
# 2026-04-21,14:12:55 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 9/20, learning_rate=0.001156
# 2026-04-21,14:12:55 | INFO |   Batch 0 / 5959: loss=0.801204 cross_entropy_loss=9.778763
# 2026-04-21,14:12:56 | INFO |   Batch 200 / 5959: loss=0.817647 cross_entropy_loss=10.387353
# 2026-04-21,14:12:58 | INFO |   Batch 400 / 5959: loss=0.828139 cross_entropy_loss=9.950813
# 2026-04-21,14:13:00 | INFO |   Batch 600 / 5959: loss=0.834366 cross_entropy_loss=9.743193
# 2026-04-21,14:13:02 | INFO |   Batch 800 / 5959: loss=0.848721 cross_entropy_loss=10.161543
# 2026-04-21,14:13:04 | INFO |   Batch 1000 / 5959: loss=0.828911 cross_entropy_loss=10.214661
# 2026-04-21,14:13:05 | INFO |   Batch 1200 / 5959: loss=0.831944 cross_entropy_loss=10.093254
# 2026-04-21,14:13:07 | INFO |   Batch 1400 / 5959: loss=0.841244 cross_entropy_loss=9.936411
# 2026-04-21,14:13:09 | INFO |   Batch 1600 / 5959: loss=0.812048 cross_entropy_loss=10.086018
# 2026-04-21,14:13:11 | INFO |   Batch 1800 / 5959: loss=0.833485 cross_entropy_loss=9.780315
# 2026-04-21,14:13:13 | INFO |   Batch 2000 / 5959: loss=0.824847 cross_entropy_loss=10.268564
# 2026-04-21,14:13:14 | INFO |   Batch 2200 / 5959: loss=0.810566 cross_entropy_loss=9.900705
# 2026-04-21,14:13:16 | INFO |   Batch 2400 / 5959: loss=0.827096 cross_entropy_loss=10.203135
# 2026-04-21,14:13:18 | INFO |   Batch 2600 / 5959: loss=0.823582 cross_entropy_loss=10.067776
# 2026-04-21,14:13:20 | INFO |   Batch 2800 / 5959: loss=0.819878 cross_entropy_loss=10.223047
# 2026-04-21,14:13:22 | INFO |   Batch 3000 / 5959: loss=0.777433 cross_entropy_loss=10.310713
# 2026-04-21,14:13:23 | INFO |   Batch 3200 / 5959: loss=0.850485 cross_entropy_loss=10.772177
# 2026-04-21,14:13:25 | INFO |   Batch 3400 / 5959: loss=0.821446 cross_entropy_loss=10.440754
# 2026-04-21,14:13:27 | INFO |   Batch 3600 / 5959: loss=0.818689 cross_entropy_loss=10.345150
# 2026-04-21,14:13:29 | INFO |   Batch 3800 / 5959: loss=0.814211 cross_entropy_loss=10.114807
# 2026-04-21,14:13:31 | INFO |   Batch 4000 / 5959: loss=0.818678 cross_entropy_loss=10.050324
# 2026-04-21,14:13:32 | INFO |   Batch 4200 / 5959: loss=0.833456 cross_entropy_loss=10.500598
# 2026-04-21,14:13:34 | INFO |   Batch 4400 / 5959: loss=0.830105 cross_entropy_loss=10.154318
# 2026-04-21,14:13:36 | INFO |   Batch 4600 / 5959: loss=0.806317 cross_entropy_loss=10.060143
# 2026-04-21,14:13:38 | INFO |   Batch 4800 / 5959: loss=0.752374 cross_entropy_loss=9.903187
# 2026-04-21,14:13:40 | INFO |   Batch 5000 / 5959: loss=0.764168 cross_entropy_loss=9.725346
# 2026-04-21,14:13:41 | INFO |   Batch 5200 / 5959: loss=0.847577 cross_entropy_loss=10.862561
# 2026-04-21,14:13:43 | INFO |   Batch 5400 / 5959: loss=0.790792 cross_entropy_loss=10.298447
# 2026-04-21,14:13:45 | INFO |   Batch 5600 / 5959: loss=0.799477 cross_entropy_loss=10.549412
# 2026-04-21,14:13:47 | INFO |   Batch 5800 / 5959: loss=0.768459 cross_entropy_loss=9.785816
# 2026-04-21,14:13:48 | INFO | Evaluating on validation set
# 2026-04-21,14:13:48 | INFO |   Batch 0 / 745: loss=10.497768
# 2026-04-21,14:13:49 | INFO |   Batch 200 / 745: loss=10.521218
# 2026-04-21,14:13:49 | INFO |   Batch 400 / 745: loss=10.904917
# 2026-04-21,14:13:50 | INFO |   Batch 600 / 745: loss=10.382113
# 2026-04-21,14:13:50 | INFO | exp4_cfg03_scent_tis_proxy | epoch=9 train_ce=10.246339 val_loss=10.551543 val_acc=0.134321 best_val_acc=0.134321 best_test_acc=0.000000
# 2026-04-21,14:13:51 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 10/20, learning_rate=0.001000
# 2026-04-21,14:13:51 | INFO |   Batch 0 / 5959: loss=0.848066 cross_entropy_loss=10.057157
# 2026-04-21,14:13:52 | INFO |   Batch 200 / 5959: loss=0.863191 cross_entropy_loss=10.298121
# 2026-04-21,14:13:54 | INFO |   Batch 400 / 5959: loss=0.849052 cross_entropy_loss=10.417265
# 2026-04-21,14:13:56 | INFO |   Batch 600 / 5959: loss=0.815544 cross_entropy_loss=9.846799
# 2026-04-21,14:13:58 | INFO |   Batch 800 / 5959: loss=0.810399 cross_entropy_loss=10.143597
# 2026-04-21,14:14:00 | INFO |   Batch 1000 / 5959: loss=0.836728 cross_entropy_loss=9.808638
# 2026-04-21,14:14:01 | INFO |   Batch 1200 / 5959: loss=0.843202 cross_entropy_loss=9.907937
# 2026-04-21,14:14:03 | INFO |   Batch 1400 / 5959: loss=0.862876 cross_entropy_loss=10.460659
# 2026-04-21,14:14:05 | INFO |   Batch 1600 / 5959: loss=0.858486 cross_entropy_loss=10.776358
# 2026-04-21,14:14:07 | INFO |   Batch 1800 / 5959: loss=0.837094 cross_entropy_loss=10.442664
# 2026-04-21,14:14:09 | INFO |   Batch 2000 / 5959: loss=0.787971 cross_entropy_loss=9.943861
# 2026-04-21,14:14:10 | INFO |   Batch 2200 / 5959: loss=0.822914 cross_entropy_loss=9.779556
# 2026-04-21,14:14:12 | INFO |   Batch 2400 / 5959: loss=0.830549 cross_entropy_loss=10.544728
# 2026-04-21,14:14:14 | INFO |   Batch 2600 / 5959: loss=0.837184 cross_entropy_loss=10.619095
# 2026-04-21,14:14:16 | INFO |   Batch 2800 / 5959: loss=0.818718 cross_entropy_loss=10.030089
# 2026-04-21,14:14:18 | INFO |   Batch 3000 / 5959: loss=0.798332 cross_entropy_loss=9.935627
# 2026-04-21,14:14:19 | INFO |   Batch 3200 / 5959: loss=0.796333 cross_entropy_loss=10.324554
# 2026-04-21,14:14:21 | INFO |   Batch 3400 / 5959: loss=0.802279 cross_entropy_loss=9.709921
# 2026-04-21,14:14:23 | INFO |   Batch 3600 / 5959: loss=0.802866 cross_entropy_loss=9.324469
# 2026-04-21,14:14:25 | INFO |   Batch 3800 / 5959: loss=0.772582 cross_entropy_loss=9.050360
# 2026-04-21,14:14:27 | INFO |   Batch 4000 / 5959: loss=0.814414 cross_entropy_loss=11.037981
# 2026-04-21,14:14:28 | INFO |   Batch 4200 / 5959: loss=0.816782 cross_entropy_loss=10.368776
# 2026-04-21,14:14:30 | INFO |   Batch 4400 / 5959: loss=0.846677 cross_entropy_loss=10.676924
# 2026-04-21,14:14:32 | INFO |   Batch 4600 / 5959: loss=0.832140 cross_entropy_loss=9.999965
# 2026-04-21,14:14:34 | INFO |   Batch 4800 / 5959: loss=0.851522 cross_entropy_loss=10.755522
# 2026-04-21,14:14:36 | INFO |   Batch 5000 / 5959: loss=0.836863 cross_entropy_loss=10.041156
# 2026-04-21,14:14:37 | INFO |   Batch 5200 / 5959: loss=0.822058 cross_entropy_loss=10.314635
# 2026-04-21,14:14:39 | INFO |   Batch 5400 / 5959: loss=0.843409 cross_entropy_loss=10.629855
# 2026-04-21,14:14:41 | INFO |   Batch 5600 / 5959: loss=0.823927 cross_entropy_loss=10.409088
# 2026-04-21,14:14:43 | INFO |   Batch 5800 / 5959: loss=0.822428 cross_entropy_loss=10.130713
# 2026-04-21,14:14:44 | INFO | Evaluating on validation set
# 2026-04-21,14:14:44 | INFO |   Batch 0 / 745: loss=10.547655
# 2026-04-21,14:14:45 | INFO |   Batch 200 / 745: loss=10.592100
# 2026-04-21,14:14:45 | INFO |   Batch 400 / 745: loss=10.963442
# 2026-04-21,14:14:45 | INFO |   Batch 600 / 745: loss=10.450291
# 2026-04-21,14:14:46 | INFO | exp4_cfg03_scent_tis_proxy | epoch=10 train_ce=10.277985 val_loss=10.608065 val_acc=0.134353 best_val_acc=0.134353 best_test_acc=0.000000
# 2026-04-21,14:14:46 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 11/20, learning_rate=0.000844
# 2026-04-21,14:14:46 | INFO |   Batch 0 / 5959: loss=0.850609 cross_entropy_loss=10.340350
# 2026-04-21,14:14:48 | INFO |   Batch 200 / 5959: loss=0.857817 cross_entropy_loss=10.281759
# 2026-04-21,14:14:50 | INFO |   Batch 400 / 5959: loss=0.892105 cross_entropy_loss=10.482818
# 2026-04-21,14:14:52 | INFO |   Batch 600 / 5959: loss=0.833351 cross_entropy_loss=10.634002
# 2026-04-21,14:14:54 | INFO |   Batch 800 / 5959: loss=0.820781 cross_entropy_loss=10.094437
# 2026-04-21,14:14:56 | INFO |   Batch 1000 / 5959: loss=0.847528 cross_entropy_loss=10.061623
# 2026-04-21,14:14:57 | INFO |   Batch 1200 / 5959: loss=0.841154 cross_entropy_loss=9.731988
# 2026-04-21,14:14:59 | INFO |   Batch 1400 / 5959: loss=0.835771 cross_entropy_loss=10.619005
# 2026-04-21,14:15:01 | INFO |   Batch 1600 / 5959: loss=0.843792 cross_entropy_loss=10.980490
# 2026-04-21,14:15:03 | INFO |   Batch 1800 / 5959: loss=0.880480 cross_entropy_loss=11.130346
# 2026-04-21,14:15:05 | INFO |   Batch 2000 / 5959: loss=0.857735 cross_entropy_loss=10.648991
# 2026-04-21,14:15:06 | INFO |   Batch 2200 / 5959: loss=0.824604 cross_entropy_loss=9.588644
# 2026-04-21,14:15:08 | INFO |   Batch 2400 / 5959: loss=0.818370 cross_entropy_loss=10.327996
# 2026-04-21,14:15:10 | INFO |   Batch 2600 / 5959: loss=0.809857 cross_entropy_loss=9.887178
# 2026-04-21,14:15:12 | INFO |   Batch 2800 / 5959: loss=0.817366 cross_entropy_loss=9.976164
# 2026-04-21,14:15:14 | INFO |   Batch 3000 / 5959: loss=0.821490 cross_entropy_loss=10.182964
# 2026-04-21,14:15:15 | INFO |   Batch 3200 / 5959: loss=0.871644 cross_entropy_loss=10.443516
# 2026-04-21,14:15:17 | INFO |   Batch 3400 / 5959: loss=0.803659 cross_entropy_loss=10.290562
# 2026-04-21,14:15:19 | INFO |   Batch 3600 / 5959: loss=0.791130 cross_entropy_loss=9.876681
# 2026-04-21,14:15:21 | INFO |   Batch 3800 / 5959: loss=0.852346 cross_entropy_loss=10.225424
# 2026-04-21,14:15:23 | INFO |   Batch 4000 / 5959: loss=0.837663 cross_entropy_loss=9.912298
# 2026-04-21,14:15:24 | INFO |   Batch 4200 / 5959: loss=0.851033 cross_entropy_loss=9.858803
# 2026-04-21,14:15:26 | INFO |   Batch 4400 / 5959: loss=0.866961 cross_entropy_loss=10.391714
# 2026-04-21,14:15:28 | INFO |   Batch 4600 / 5959: loss=0.851717 cross_entropy_loss=11.087066
# 2026-04-21,14:15:30 | INFO |   Batch 4800 / 5959: loss=0.838944 cross_entropy_loss=10.873469
# 2026-04-21,14:15:32 | INFO |   Batch 5000 / 5959: loss=0.782544 cross_entropy_loss=9.844068
# 2026-04-21,14:15:33 | INFO |   Batch 5200 / 5959: loss=0.873595 cross_entropy_loss=10.781792
# 2026-04-21,14:15:35 | INFO |   Batch 5400 / 5959: loss=0.798803 cross_entropy_loss=10.175667
# 2026-04-21,14:15:37 | INFO |   Batch 5600 / 5959: loss=0.794759 cross_entropy_loss=9.998492
# 2026-04-21,14:15:39 | INFO |   Batch 5800 / 5959: loss=0.844403 cross_entropy_loss=10.591700
# 2026-04-21,14:15:40 | INFO | Evaluating on validation set
# 2026-04-21,14:15:40 | INFO |   Batch 0 / 745: loss=10.594410
# 2026-04-21,14:15:41 | INFO |   Batch 200 / 745: loss=10.656142
# 2026-04-21,14:15:41 | INFO |   Batch 400 / 745: loss=11.023474
# 2026-04-21,14:15:42 | INFO |   Batch 600 / 745: loss=10.513250
# 2026-04-21,14:15:42 | INFO | exp4_cfg03_scent_tis_proxy | epoch=11 train_ce=10.312559 val_loss=10.663350 val_acc=0.134437 best_val_acc=0.134437 best_test_acc=0.000000
# 2026-04-21,14:15:43 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 12/20, learning_rate=0.000691
# 2026-04-21,14:15:43 | INFO |   Batch 0 / 5959: loss=0.827156 cross_entropy_loss=10.135834
# 2026-04-21,14:15:44 | INFO |   Batch 200 / 5959: loss=0.859340 cross_entropy_loss=10.780349
# 2026-04-21,14:15:46 | INFO |   Batch 400 / 5959: loss=0.872837 cross_entropy_loss=10.203238
# 2026-04-21,14:15:48 | INFO |   Batch 600 / 5959: loss=0.857293 cross_entropy_loss=10.356804
# 2026-04-21,14:15:50 | INFO |   Batch 800 / 5959: loss=0.817733 cross_entropy_loss=10.402275
# 2026-04-21,14:15:52 | INFO |   Batch 1000 / 5959: loss=0.852474 cross_entropy_loss=10.316967
# 2026-04-21,14:15:53 | INFO |   Batch 1200 / 5959: loss=0.880848 cross_entropy_loss=10.514685
# 2026-04-21,14:15:55 | INFO |   Batch 1400 / 5959: loss=0.893046 cross_entropy_loss=10.436725
# 2026-04-21,14:15:57 | INFO |   Batch 1600 / 5959: loss=0.900185 cross_entropy_loss=10.974850
# 2026-04-21,14:15:59 | INFO |   Batch 1800 / 5959: loss=0.874712 cross_entropy_loss=10.934109
# 2026-04-21,14:16:01 | INFO |   Batch 2000 / 5959: loss=0.868286 cross_entropy_loss=10.800904
# 2026-04-21,14:16:02 | INFO |   Batch 2200 / 5959: loss=0.870600 cross_entropy_loss=11.133764
# 2026-04-21,14:16:04 | INFO |   Batch 2400 / 5959: loss=0.857374 cross_entropy_loss=10.594018
# 2026-04-21,14:16:06 | INFO |   Batch 2600 / 5959: loss=0.860596 cross_entropy_loss=9.711690
# 2026-04-21,14:16:08 | INFO |   Batch 2800 / 5959: loss=0.845551 cross_entropy_loss=10.528352
# 2026-04-21,14:16:10 | INFO |   Batch 3000 / 5959: loss=0.836949 cross_entropy_loss=9.856195
# 2026-04-21,14:16:11 | INFO |   Batch 3200 / 5959: loss=0.858959 cross_entropy_loss=10.390104
# 2026-04-21,14:16:13 | INFO |   Batch 3400 / 5959: loss=0.858550 cross_entropy_loss=10.363121
# 2026-04-21,14:16:15 | INFO |   Batch 3600 / 5959: loss=0.881849 cross_entropy_loss=10.998312
# 2026-04-21,14:16:17 | INFO |   Batch 3800 / 5959: loss=0.857278 cross_entropy_loss=10.290709
# 2026-04-21,14:16:19 | INFO |   Batch 4000 / 5959: loss=0.829501 cross_entropy_loss=10.300422
# 2026-04-21,14:16:20 | INFO |   Batch 4200 / 5959: loss=0.832178 cross_entropy_loss=10.559286
# 2026-04-21,14:16:22 | INFO |   Batch 4400 / 5959: loss=0.809268 cross_entropy_loss=10.756075
# 2026-04-21,14:16:24 | INFO |   Batch 4600 / 5959: loss=0.850075 cross_entropy_loss=10.268649
# 2026-04-21,14:16:26 | INFO |   Batch 4800 / 5959: loss=0.851691 cross_entropy_loss=10.735840
# 2026-04-21,14:16:28 | INFO |   Batch 5000 / 5959: loss=0.821306 cross_entropy_loss=10.103148
# 2026-04-21,14:16:29 | INFO |   Batch 5200 / 5959: loss=0.855927 cross_entropy_loss=10.766937
# 2026-04-21,14:16:31 | INFO |   Batch 5400 / 5959: loss=0.837288 cross_entropy_loss=10.283260
# 2026-04-21,14:16:33 | INFO |   Batch 5600 / 5959: loss=0.811725 cross_entropy_loss=10.023148
# 2026-04-21,14:16:35 | INFO |   Batch 5800 / 5959: loss=0.871037 cross_entropy_loss=10.309161
# 2026-04-21,14:16:36 | INFO | Evaluating on validation set
# 2026-04-21,14:16:36 | INFO |   Batch 0 / 745: loss=10.641077
# 2026-04-21,14:16:37 | INFO |   Batch 200 / 745: loss=10.717798
# 2026-04-21,14:16:37 | INFO |   Batch 400 / 745: loss=11.079526
# 2026-04-21,14:16:37 | INFO |   Batch 600 / 745: loss=10.573719
# 2026-04-21,14:16:38 | INFO | exp4_cfg03_scent_tis_proxy | epoch=12 train_ce=10.347773 val_loss=10.715602 val_acc=0.134447 best_val_acc=0.134447 best_test_acc=0.000000
# 2026-04-21,14:16:38 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 13/20, learning_rate=0.000546
# 2026-04-21,14:16:38 | INFO |   Batch 0 / 5959: loss=0.890947 cross_entropy_loss=10.521786
# 2026-04-21,14:16:40 | INFO |   Batch 200 / 5959: loss=0.866877 cross_entropy_loss=10.426303
# 2026-04-21,14:16:42 | INFO |   Batch 400 / 5959: loss=0.832766 cross_entropy_loss=10.098852
# 2026-04-21,14:16:44 | INFO |   Batch 600 / 5959: loss=0.896601 cross_entropy_loss=10.598320
# 2026-04-21,14:16:46 | INFO |   Batch 800 / 5959: loss=0.855310 cross_entropy_loss=10.669357
# 2026-04-21,14:16:47 | INFO |   Batch 1000 / 5959: loss=0.900170 cross_entropy_loss=10.411882
# 2026-04-21,14:16:49 | INFO |   Batch 1200 / 5959: loss=0.849346 cross_entropy_loss=10.376530
# 2026-04-21,14:16:51 | INFO |   Batch 1400 / 5959: loss=0.869421 cross_entropy_loss=10.630331
# 2026-04-21,14:16:53 | INFO |   Batch 1600 / 5959: loss=0.837090 cross_entropy_loss=9.716532
# 2026-04-21,14:16:55 | INFO |   Batch 1800 / 5959: loss=0.844018 cross_entropy_loss=10.694208
# 2026-04-21,14:16:56 | INFO |   Batch 2000 / 5959: loss=0.856881 cross_entropy_loss=10.568260
# 2026-04-21,14:16:58 | INFO |   Batch 2200 / 5959: loss=0.848487 cross_entropy_loss=10.092303
# 2026-04-21,14:17:00 | INFO |   Batch 2400 / 5959: loss=0.866897 cross_entropy_loss=10.220898
# 2026-04-21,14:17:02 | INFO |   Batch 2600 / 5959: loss=0.827699 cross_entropy_loss=10.226454
# 2026-04-21,14:17:04 | INFO |   Batch 2800 / 5959: loss=0.875257 cross_entropy_loss=10.798404
# 2026-04-21,14:17:05 | INFO |   Batch 3000 / 5959: loss=0.878759 cross_entropy_loss=10.188264
# 2026-04-21,14:17:07 | INFO |   Batch 3200 / 5959: loss=0.894014 cross_entropy_loss=10.644493
# 2026-04-21,14:17:09 | INFO |   Batch 3400 / 5959: loss=0.856711 cross_entropy_loss=10.736333
# 2026-04-21,14:17:11 | INFO |   Batch 3600 / 5959: loss=0.894831 cross_entropy_loss=10.587711
# 2026-04-21,14:17:13 | INFO |   Batch 3800 / 5959: loss=0.875058 cross_entropy_loss=10.470722
# 2026-04-21,14:17:14 | INFO |   Batch 4000 / 5959: loss=0.858797 cross_entropy_loss=10.962644
# 2026-04-21,14:17:16 | INFO |   Batch 4200 / 5959: loss=0.872342 cross_entropy_loss=10.627769
# 2026-04-21,14:17:18 | INFO |   Batch 4400 / 5959: loss=0.838448 cross_entropy_loss=10.237938
# 2026-04-21,14:17:20 | INFO |   Batch 4600 / 5959: loss=0.830137 cross_entropy_loss=10.277609
# 2026-04-21,14:17:22 | INFO |   Batch 4800 / 5959: loss=0.887373 cross_entropy_loss=11.008620
# 2026-04-21,14:17:23 | INFO |   Batch 5000 / 5959: loss=0.845079 cross_entropy_loss=9.754820
# 2026-04-21,14:17:25 | INFO |   Batch 5200 / 5959: loss=0.829171 cross_entropy_loss=9.821455
# 2026-04-21,14:17:27 | INFO |   Batch 5400 / 5959: loss=0.859297 cross_entropy_loss=10.201409
# 2026-04-21,14:17:29 | INFO |   Batch 5600 / 5959: loss=0.797988 cross_entropy_loss=9.456068
# 2026-04-21,14:17:31 | INFO |   Batch 5800 / 5959: loss=0.852763 cross_entropy_loss=10.568496
# 2026-04-21,14:17:32 | INFO | Evaluating on validation set
# 2026-04-21,14:17:32 | INFO |   Batch 0 / 745: loss=10.685606
# 2026-04-21,14:17:33 | INFO |   Batch 200 / 745: loss=10.772625
# 2026-04-21,14:17:33 | INFO |   Batch 400 / 745: loss=11.128908
# 2026-04-21,14:17:33 | INFO |   Batch 600 / 745: loss=10.630493
# 2026-04-21,14:17:34 | INFO | exp4_cfg03_scent_tis_proxy | epoch=13 train_ce=10.382983 val_loss=10.763865 val_acc=0.134521 best_val_acc=0.134521 best_test_acc=0.000000
# 2026-04-21,14:17:34 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 14/20, learning_rate=0.000412
# 2026-04-21,14:17:34 | INFO |   Batch 0 / 5959: loss=0.882448 cross_entropy_loss=10.597541
# 2026-04-21,14:17:36 | INFO |   Batch 200 / 5959: loss=0.849843 cross_entropy_loss=10.544806
# 2026-04-21,14:17:38 | INFO |   Batch 400 / 5959: loss=0.877877 cross_entropy_loss=9.880133
# 2026-04-21,14:17:40 | INFO |   Batch 600 / 5959: loss=0.891458 cross_entropy_loss=10.640075
# 2026-04-21,14:17:42 | INFO |   Batch 800 / 5959: loss=0.879810 cross_entropy_loss=10.503157
# 2026-04-21,14:17:43 | INFO |   Batch 1000 / 5959: loss=0.861928 cross_entropy_loss=10.453988
# 2026-04-21,14:17:45 | INFO |   Batch 1200 / 5959: loss=0.841314 cross_entropy_loss=9.753227
# 2026-04-21,14:17:47 | INFO |   Batch 1400 / 5959: loss=0.884661 cross_entropy_loss=10.195970
# 2026-04-21,14:17:49 | INFO |   Batch 1600 / 5959: loss=0.882398 cross_entropy_loss=10.170388
# 2026-04-21,14:17:51 | INFO |   Batch 1800 / 5959: loss=0.838284 cross_entropy_loss=10.073178
# 2026-04-21,14:17:52 | INFO |   Batch 2000 / 5959: loss=0.877698 cross_entropy_loss=10.305761
# 2026-04-21,14:17:54 | INFO |   Batch 2200 / 5959: loss=0.920004 cross_entropy_loss=10.727983
# 2026-04-21,14:17:56 | INFO |   Batch 2400 / 5959: loss=0.887766 cross_entropy_loss=10.183865
# 2026-04-21,14:17:58 | INFO |   Batch 2600 / 5959: loss=0.889210 cross_entropy_loss=9.830570
# 2026-04-21,14:18:00 | INFO |   Batch 2800 / 5959: loss=0.891027 cross_entropy_loss=10.781433
# 2026-04-21,14:18:01 | INFO |   Batch 3000 / 5959: loss=0.834283 cross_entropy_loss=9.678113
# 2026-04-21,14:18:03 | INFO |   Batch 3200 / 5959: loss=0.859318 cross_entropy_loss=10.482742
# 2026-04-21,14:18:05 | INFO |   Batch 3400 / 5959: loss=0.860641 cross_entropy_loss=11.001625
# 2026-04-21,14:18:07 | INFO |   Batch 3600 / 5959: loss=0.853529 cross_entropy_loss=10.783583
# 2026-04-21,14:18:09 | INFO |   Batch 3800 / 5959: loss=0.840626 cross_entropy_loss=9.820152
# 2026-04-21,14:18:10 | INFO |   Batch 4000 / 5959: loss=0.847094 cross_entropy_loss=10.219610
# 2026-04-21,14:18:12 | INFO |   Batch 4200 / 5959: loss=0.878769 cross_entropy_loss=10.276814
# 2026-04-21,14:18:14 | INFO |   Batch 4400 / 5959: loss=0.864436 cross_entropy_loss=10.802217
# 2026-04-21,14:18:16 | INFO |   Batch 4600 / 5959: loss=0.871356 cross_entropy_loss=10.286228
# 2026-04-21,14:18:18 | INFO |   Batch 4800 / 5959: loss=0.875812 cross_entropy_loss=10.806400
# 2026-04-21,14:18:19 | INFO |   Batch 5000 / 5959: loss=0.889406 cross_entropy_loss=10.341699
# 2026-04-21,14:18:21 | INFO |   Batch 5200 / 5959: loss=0.914928 cross_entropy_loss=10.783958
# 2026-04-21,14:18:23 | INFO |   Batch 5400 / 5959: loss=0.876377 cross_entropy_loss=11.060523
# 2026-04-21,14:18:25 | INFO |   Batch 5600 / 5959: loss=0.874909 cross_entropy_loss=11.166292
# 2026-04-21,14:18:27 | INFO |   Batch 5800 / 5959: loss=0.889400 cross_entropy_loss=10.819628
# 2026-04-21,14:18:28 | INFO | Evaluating on validation set
# 2026-04-21,14:18:28 | INFO |   Batch 0 / 745: loss=10.722363
# 2026-04-21,14:18:28 | INFO |   Batch 200 / 745: loss=10.822807
# 2026-04-21,14:18:29 | INFO |   Batch 400 / 745: loss=11.173529
# 2026-04-21,14:18:29 | INFO |   Batch 600 / 745: loss=10.676962
# 2026-04-21,14:18:30 | INFO | exp4_cfg03_scent_tis_proxy | epoch=14 train_ce=10.416536 val_loss=10.806964 val_acc=0.134563 best_val_acc=0.134563 best_test_acc=0.000000
# 2026-04-21,14:18:30 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 15/20, learning_rate=0.000293
# 2026-04-21,14:18:30 | INFO |   Batch 0 / 5959: loss=0.906063 cross_entropy_loss=10.480236
# 2026-04-21,14:18:32 | INFO |   Batch 200 / 5959: loss=0.872234 cross_entropy_loss=10.052099
# 2026-04-21,14:18:34 | INFO |   Batch 400 / 5959: loss=0.910698 cross_entropy_loss=10.707188
# 2026-04-21,14:18:36 | INFO |   Batch 600 / 5959: loss=0.878317 cross_entropy_loss=10.325017
# 2026-04-21,14:18:37 | INFO |   Batch 800 / 5959: loss=0.900596 cross_entropy_loss=11.116623
# 2026-04-21,14:18:39 | INFO |   Batch 1000 / 5959: loss=0.868336 cross_entropy_loss=9.596466
# 2026-04-21,14:18:41 | INFO |   Batch 1200 / 5959: loss=0.833753 cross_entropy_loss=10.573015
# 2026-04-21,14:18:43 | INFO |   Batch 1400 / 5959: loss=0.870454 cross_entropy_loss=10.044355
# 2026-04-21,14:18:45 | INFO |   Batch 1600 / 5959: loss=0.876862 cross_entropy_loss=10.137777
# 2026-04-21,14:18:46 | INFO |   Batch 1800 / 5959: loss=0.897803 cross_entropy_loss=10.108833
# 2026-04-21,14:18:48 | INFO |   Batch 2000 / 5959: loss=0.853217 cross_entropy_loss=9.498079
# ...
# 2026-04-21,14:20:55 | INFO |   Batch 3600 / 5959: loss=0.908723 cross_entropy_loss=10.788061
# 2026-04-21,14:20:56 | INFO |   Batch 3800 / 5959: loss=0.882098 cross_entropy_loss=10.189705
# 2026-04-21,14:20:58 | INFO |   Batch 4000 / 5959: loss=0.872007 cross_entropy_loss=10.418381
# 2026-04-21,14:21:00 | INFO |   Batch 4200 / 5959: loss=0.923435 cross_entropy_loss=10.295361
# 2026-04-21,14:21:02 | INFO |   Batch 4400 / 5959: loss=0.881130 cross_entropy_loss=10.385106
# 2026-04-21,14:21:04 | INFO |   Batch 4600 / 5959: loss=0.889756 cross_entropy_loss=10.272278
# 2026-04-21,14:21:05 | INFO |   Batch 4800 / 5959: loss=0.906044 cross_entropy_loss=10.382601
# 2026-04-21,14:21:07 | INFO |   Batch 5000 / 5959: loss=0.901782 cross_entropy_loss=9.625452
# 2026-04-21,14:21:09 | INFO |   Batch 5200 / 5959: loss=0.898084 cross_entropy_loss=9.676749
# 2026-04-21,14:21:11 | INFO |   Batch 5400 / 5959: loss=0.890696 cross_entropy_loss=10.261522
# 2026-04-21,14:21:13 | INFO |   Batch 5600 / 5959: loss=0.906806 cross_entropy_loss=10.175999
# 2026-04-21,14:21:14 | INFO |   Batch 5800 / 5959: loss=0.887460 cross_entropy_loss=10.351613
# 2026-04-21,14:21:16 | INFO | Evaluating on validation set
# 2026-04-21,14:21:16 | INFO |   Batch 0 / 745: loss=10.800138
# 2026-04-21,14:21:16 | INFO |   Batch 200 / 745: loss=10.919971
# 2026-04-21,14:21:17 | INFO |   Batch 400 / 745: loss=11.263543
# 2026-04-21,14:21:17 | INFO |   Batch 600 / 745: loss=10.771610
# 2026-04-21,14:21:17 | INFO | exp4_cfg03_scent_tis_proxy | epoch=17 train_ce=10.494346 val_loss=10.892894 val_acc=0.134573 best_val_acc=0.134573 best_test_acc=0.000000
# 2026-04-21,14:21:18 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 18/20, learning_rate=0.000049
# 2026-04-21,14:21:18 | INFO |   Batch 0 / 5959: loss=0.896822 cross_entropy_loss=10.330431
# 2026-04-21,14:21:20 | INFO |   Batch 200 / 5959: loss=0.909151 cross_entropy_loss=11.102960
# 2026-04-21,14:21:22 | INFO |   Batch 400 / 5959: loss=0.913300 cross_entropy_loss=10.292013
# 2026-04-21,14:21:24 | INFO |   Batch 600 / 5959: loss=0.913130 cross_entropy_loss=11.208637
# 2026-04-21,14:21:25 | INFO |   Batch 800 / 5959: loss=0.929968 cross_entropy_loss=10.958599
# 2026-04-21,14:21:27 | INFO |   Batch 1000 / 5959: loss=0.843146 cross_entropy_loss=10.408442
# 2026-04-21,14:21:29 | INFO |   Batch 1200 / 5959: loss=0.951942 cross_entropy_loss=10.078117
# 2026-04-21,14:21:31 | INFO |   Batch 1400 / 5959: loss=0.903991 cross_entropy_loss=10.131036
# 2026-04-21,14:21:33 | INFO |   Batch 1600 / 5959: loss=0.955093 cross_entropy_loss=10.848471
# 2026-04-21,14:21:34 | INFO |   Batch 1800 / 5959: loss=0.910619 cross_entropy_loss=10.512525
# 2026-04-21,14:21:36 | INFO |   Batch 2000 / 5959: loss=0.903464 cross_entropy_loss=10.075321
# 2026-04-21,14:21:38 | INFO |   Batch 2200 / 5959: loss=0.888998 cross_entropy_loss=9.959578
# 2026-04-21,14:21:40 | INFO |   Batch 2400 / 5959: loss=0.922971 cross_entropy_loss=10.927162
# 2026-04-21,14:21:42 | INFO |   Batch 2600 / 5959: loss=0.865717 cross_entropy_loss=9.978863
# 2026-04-21,14:21:43 | INFO |   Batch 2800 / 5959: loss=0.933371 cross_entropy_loss=10.529787
# 2026-04-21,14:21:45 | INFO |   Batch 3000 / 5959: loss=0.945074 cross_entropy_loss=10.118295
# 2026-04-21,14:21:47 | INFO |   Batch 3200 / 5959: loss=0.914824 cross_entropy_loss=10.423605
# 2026-04-21,14:21:49 | INFO |   Batch 3400 / 5959: loss=0.910645 cross_entropy_loss=10.815874
# 2026-04-21,14:21:51 | INFO |   Batch 3600 / 5959: loss=0.914006 cross_entropy_loss=10.842299
# 2026-04-21,14:21:52 | INFO |   Batch 3800 / 5959: loss=0.933736 cross_entropy_loss=10.468853
# 2026-04-21,14:21:54 | INFO |   Batch 4000 / 5959: loss=0.918838 cross_entropy_loss=10.326307
# 2026-04-21,14:21:56 | INFO |   Batch 4200 / 5959: loss=0.921288 cross_entropy_loss=11.212537
# 2026-04-21,14:21:58 | INFO |   Batch 4400 / 5959: loss=0.928630 cross_entropy_loss=10.016718
# 2026-04-21,14:22:00 | INFO |   Batch 4600 / 5959: loss=0.895396 cross_entropy_loss=9.897425
# 2026-04-21,14:22:01 | INFO |   Batch 4800 / 5959: loss=0.943700 cross_entropy_loss=10.621987
# 2026-04-21,14:22:03 | INFO |   Batch 5000 / 5959: loss=0.952336 cross_entropy_loss=11.341936
# 2026-04-21,14:22:05 | INFO |   Batch 5200 / 5959: loss=0.876329 cross_entropy_loss=9.556226
# 2026-04-21,14:22:07 | INFO |   Batch 5400 / 5959: loss=0.894605 cross_entropy_loss=10.582069
# 2026-04-21,14:22:09 | INFO |   Batch 5600 / 5959: loss=0.915723 cross_entropy_loss=10.180468
# 2026-04-21,14:22:10 | INFO |   Batch 5800 / 5959: loss=0.939615 cross_entropy_loss=11.003157
# 2026-04-21,14:22:12 | INFO | Evaluating on validation set
# 2026-04-21,14:22:12 | INFO |   Batch 0 / 745: loss=10.810675
# 2026-04-21,14:22:12 | INFO |   Batch 200 / 745: loss=10.933075
# 2026-04-21,14:22:13 | INFO |   Batch 400 / 745: loss=11.275616
# 2026-04-21,14:22:13 | INFO |   Batch 600 / 745: loss=10.784125
# 2026-04-21,14:22:13 | INFO | exp4_cfg03_scent_tis_proxy | epoch=18 train_ce=10.508083 val_loss=10.904433 val_acc=0.134594 best_val_acc=0.134594 best_test_acc=0.000000
# 2026-04-21,14:22:14 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 19/20, learning_rate=0.000012
# 2026-04-21,14:22:14 | INFO |   Batch 0 / 5959: loss=0.976170 cross_entropy_loss=10.526686
# 2026-04-21,14:22:16 | INFO |   Batch 200 / 5959: loss=0.909729 cross_entropy_loss=10.943039
# 2026-04-21,14:22:18 | INFO |   Batch 400 / 5959: loss=0.916869 cross_entropy_loss=10.874727
# 2026-04-21,14:22:19 | INFO |   Batch 600 / 5959: loss=0.933522 cross_entropy_loss=10.818433
# 2026-04-21,14:22:21 | INFO |   Batch 800 / 5959: loss=0.947793 cross_entropy_loss=11.408228
# 2026-04-21,14:22:23 | INFO |   Batch 1000 / 5959: loss=0.916473 cross_entropy_loss=10.474058
# 2026-04-21,14:22:25 | INFO |   Batch 1200 / 5959: loss=0.927181 cross_entropy_loss=10.599730
# 2026-04-21,14:22:27 | INFO |   Batch 1400 / 5959: loss=0.941480 cross_entropy_loss=10.413038
# 2026-04-21,14:22:29 | INFO |   Batch 1600 / 5959: loss=0.927068 cross_entropy_loss=10.205599
# 2026-04-21,14:22:30 | INFO |   Batch 1800 / 5959: loss=0.916936 cross_entropy_loss=10.153450
# 2026-04-21,14:22:32 | INFO |   Batch 2000 / 5959: loss=0.908091 cross_entropy_loss=11.069516
# 2026-04-21,14:22:34 | INFO |   Batch 2200 / 5959: loss=0.913920 cross_entropy_loss=9.861631
# 2026-04-21,14:22:36 | INFO |   Batch 2400 / 5959: loss=0.898036 cross_entropy_loss=10.655264
# 2026-04-21,14:22:38 | INFO |   Batch 2600 / 5959: loss=0.897722 cross_entropy_loss=9.896933
# 2026-04-21,14:22:39 | INFO |   Batch 2800 / 5959: loss=0.924050 cross_entropy_loss=10.092950
# 2026-04-21,14:22:41 | INFO |   Batch 3000 / 5959: loss=0.930016 cross_entropy_loss=10.241055
# 2026-04-21,14:22:43 | INFO |   Batch 3200 / 5959: loss=0.938824 cross_entropy_loss=10.856291
# 2026-04-21,14:22:45 | INFO |   Batch 3400 / 5959: loss=0.942845 cross_entropy_loss=10.956766
# 2026-04-21,14:22:46 | INFO |   Batch 3600 / 5959: loss=0.941919 cross_entropy_loss=11.191926
# 2026-04-21,14:22:48 | INFO |   Batch 3800 / 5959: loss=0.922736 cross_entropy_loss=10.343698
# 2026-04-21,14:22:50 | INFO |   Batch 4000 / 5959: loss=0.942700 cross_entropy_loss=10.783539
# 2026-04-21,14:22:52 | INFO |   Batch 4200 / 5959: loss=0.922501 cross_entropy_loss=10.324771
# 2026-04-21,14:22:54 | INFO |   Batch 4400 / 5959: loss=0.900382 cross_entropy_loss=10.469888
# 2026-04-21,14:22:56 | INFO |   Batch 4600 / 5959: loss=0.934079 cross_entropy_loss=10.179168
# 2026-04-21,14:22:57 | INFO |   Batch 4800 / 5959: loss=0.957453 cross_entropy_loss=10.308748
# 2026-04-21,14:22:59 | INFO |   Batch 5000 / 5959: loss=0.917776 cross_entropy_loss=10.931173
# 2026-04-21,14:23:01 | INFO |   Batch 5200 / 5959: loss=0.939179 cross_entropy_loss=10.383142
# 2026-04-21,14:23:03 | INFO |   Batch 5400 / 5959: loss=0.923266 cross_entropy_loss=10.704466
# 2026-04-21,14:23:05 | INFO |   Batch 5600 / 5959: loss=0.941041 cross_entropy_loss=10.138020
# 2026-04-21,14:23:06 | INFO |   Batch 5800 / 5959: loss=0.909724 cross_entropy_loss=9.840045
# 2026-04-21,14:23:08 | INFO | Evaluating on validation set
# 2026-04-21,14:23:08 | INFO |   Batch 0 / 745: loss=10.813512
# 2026-04-21,14:23:08 | INFO |   Batch 200 / 745: loss=10.936619
# 2026-04-21,14:23:09 | INFO |   Batch 400 / 745: loss=11.278882
# 2026-04-21,14:23:09 | INFO |   Batch 600 / 745: loss=10.787531
# 2026-04-21,14:23:09 | INFO | exp4_cfg03_scent_tis_proxy | epoch=19 train_ce=10.514497 val_loss=10.907534 val_acc=0.134594 best_val_acc=0.134594 best_test_acc=0.000000
# 2026-04-21,14:23:10 | INFO | exp4_cfg03_scent_tis_proxy | Epoch 20/20, learning_rate=0.000000
# 2026-04-21,14:23:10 | INFO |   Batch 0 / 5959: loss=0.941113 cross_entropy_loss=10.348534
# 2026-04-21,14:23:12 | INFO |   Batch 200 / 5959: loss=0.949652 cross_entropy_loss=9.841589
# 2026-04-21,14:23:14 | INFO |   Batch 400 / 5959: loss=0.920884 cross_entropy_loss=10.164465
# 2026-04-21,14:23:16 | INFO |   Batch 600 / 5959: loss=0.927708 cross_entropy_loss=10.459187
# 2026-04-21,14:23:17 | INFO |   Batch 800 / 5959: loss=0.916337 cross_entropy_loss=10.412678
# 2026-04-21,14:23:19 | INFO |   Batch 1000 / 5959: loss=0.919723 cross_entropy_loss=10.938957
# 2026-04-21,14:23:21 | INFO |   Batch 1200 / 5959: loss=0.934603 cross_entropy_loss=10.302917
# 2026-04-21,14:23:23 | INFO |   Batch 1400 / 5959: loss=0.955725 cross_entropy_loss=9.952818
# 2026-04-21,14:23:25 | INFO |   Batch 1600 / 5959: loss=0.933691 cross_entropy_loss=11.249094
# 2026-04-21,14:23:26 | INFO |   Batch 1800 / 5959: loss=0.887162 cross_entropy_loss=11.005108
# 2026-04-21,14:23:28 | INFO |   Batch 2000 / 5959: loss=0.935426 cross_entropy_loss=10.163736
# 2026-04-21,14:23:30 | INFO |   Batch 2200 / 5959: loss=0.916292 cross_entropy_loss=10.169875
# 2026-04-21,14:23:32 | INFO |   Batch 2400 / 5959: loss=0.963385 cross_entropy_loss=9.523870
# 2026-04-21,14:23:34 | INFO |   Batch 2600 / 5959: loss=0.955143 cross_entropy_loss=11.465847
# 2026-04-21,14:23:35 | INFO |   Batch 2800 / 5959: loss=0.949776 cross_entropy_loss=10.740816
# 2026-04-21,14:23:37 | INFO |   Batch 3000 / 5959: loss=0.922223 cross_entropy_loss=10.204049
# 2026-04-21,14:23:39 | INFO |   Batch 3200 / 5959: loss=0.926877 cross_entropy_loss=9.784271
# 2026-04-21,14:23:41 | INFO |   Batch 3400 / 5959: loss=0.927359 cross_entropy_loss=10.577113
# 2026-04-21,14:23:43 | INFO |   Batch 3600 / 5959: loss=0.929111 cross_entropy_loss=10.795391
# 2026-04-21,14:23:44 | INFO |   Batch 3800 / 5959: loss=0.943341 cross_entropy_loss=10.462121
# 2026-04-21,14:23:46 | INFO |   Batch 4000 / 5959: loss=0.922774 cross_entropy_loss=10.950085
# 2026-04-21,14:23:48 | INFO |   Batch 4200 / 5959: loss=0.938954 cross_entropy_loss=10.221809
# 2026-04-21,14:23:50 | INFO |   Batch 4400 / 5959: loss=0.929105 cross_entropy_loss=9.526169
# 2026-04-21,14:23:52 | INFO |   Batch 4600 / 5959: loss=0.955735 cross_entropy_loss=10.445848
# 2026-04-21,14:23:53 | INFO |   Batch 4800 / 5959: loss=0.940695 cross_entropy_loss=10.233459
# 2026-04-21,14:23:55 | INFO |   Batch 5000 / 5959: loss=0.955254 cross_entropy_loss=10.014831
# 2026-04-21,14:23:57 | INFO |   Batch 5200 / 5959: loss=0.931674 cross_entropy_loss=10.403961
# 2026-04-21,14:23:59 | INFO |   Batch 5400 / 5959: loss=0.934320 cross_entropy_loss=11.037844
# 2026-04-21,14:24:01 | INFO |   Batch 5600 / 5959: loss=0.925191 cross_entropy_loss=10.946696
# 2026-04-21,14:24:02 | INFO |   Batch 5800 / 5959: loss=0.922071 cross_entropy_loss=10.265608
# 2026-04-21,14:24:04 | INFO | Evaluating on validation set
# 2026-04-21,14:24:04 | INFO |   Batch 0 / 745: loss=10.813512
# 2026-04-21,14:24:04 | INFO |   Batch 200 / 745: loss=10.936619
# 2026-04-21,14:24:05 | INFO |   Batch 400 / 745: loss=11.278882
# 2026-04-21,14:24:05 | INFO |   Batch 600 / 745: loss=10.787531
# 2026-04-21,14:24:05 | INFO | exp4_cfg03_scent_tis_proxy | epoch=20 train_ce=10.515867 val_loss=10.907534 val_acc=0.134594 best_val_acc=0.134594 best_test_acc=0.000000
# [{'epoch': 1,
#   'cross_entropy_loss': 11.481356188289254,
#   'val_loss': 10.949765078664893,
#   'val_acc': 0.133859919648383,
#   'best_val_acc': 0.133859919648383,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 2,
#   'cross_entropy_loss': 10.524013137536778,
#   'val_loss': 10.412171879177436,
#   'val_acc': 0.133859919648383,
#   'best_val_acc': 0.133859919648383,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 3,
#   'cross_entropy_loss': 10.317736191994127,
#   'val_loss': 10.35987248856732,
#   'val_acc': 0.13392285825177538,
#   'best_val_acc': 0.13392285825177538,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 4,
#   'cross_entropy_loss': 10.244407675471699,
#   'val_loss': 10.349753635089293,
#   'val_acc': 0.13399628662239985,
#   'best_val_acc': 0.13399628662239985,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 5,
#   'cross_entropy_loss': 10.209347009706956,
#   'val_loss': 10.36618545287453,
#   'val_acc': 0.1340697149930243,
#   'best_val_acc': 0.1340697149930243,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 6,
#   'cross_entropy_loss': 10.196922053407992,
#   'val_loss': 10.399776914504342,
#   'val_acc': 0.13415363313088083,
#   'best_val_acc': 0.13415363313088083,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 7,
#   'cross_entropy_loss': 10.202866367647934,
#   'val_loss': 10.444431320057419,
#   'val_acc': 0.1342270615015053,
#   'best_val_acc': 0.1342270615015053,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 8,
#   'cross_entropy_loss': 10.219960481057923,
#   'val_loss': 10.496267683384891,
#   'val_acc': 0.13429000010489767,
#   'best_val_acc': 0.13429000010489767,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 9,
#   'cross_entropy_loss': 10.2463385871381,
#   'val_loss': 10.551542629027022,
#   'val_acc': 0.13432146940659387,
#   'best_val_acc': 0.13432146940659387,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 10,
#   'cross_entropy_loss': 10.277985063706959,
#   'val_loss': 10.608065296615704,
#   'val_acc': 0.13435293870829007,
#   'best_val_acc': 0.13435293870829007,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 11,
#   'cross_entropy_loss': 10.3125594768207,
#   'val_loss': 10.66334962118071,
#   'val_acc': 0.1344368568461466,
#   'best_val_acc': 0.1344368568461466,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 12,
#   'cross_entropy_loss': 10.347773254404595,
#   'val_loss': 10.715601927073832,
#   'val_acc': 0.13444734661337865,
#   'best_val_acc': 0.13444734661337865,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 13,
#   'cross_entropy_loss': 10.382982991386703,
#   'val_loss': 10.763865343097413,
#   'val_acc': 0.1345207749840031,
#   'best_val_acc': 0.1345207749840031,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 14,
#   'cross_entropy_loss': 10.416535856946824,
#   'val_loss': 10.806963777728685,
#   'val_acc': 0.13456273405293137,
#   'best_val_acc': 0.13456273405293137,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 15,
#   'cross_entropy_loss': 10.447193605629016,
#   'val_loss': 10.843354522612323,
#   'val_acc': 0.13457322382016343,
#   'best_val_acc': 0.13457322382016343,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 16,
#   'cross_entropy_loss': 10.473709311401997,
#   'val_loss': 10.872409064427789,
#   'val_acc': 0.13457322382016343,
#   'best_val_acc': 0.13457322382016343,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 17,
#   'cross_entropy_loss': 10.494346486350343,
#   'val_loss': 10.892893592612868,
#   'val_acc': 0.13457322382016343,
#   'best_val_acc': 0.13457322382016343,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 18,
#   'cross_entropy_loss': 10.508083247687509,
#   'val_loss': 10.904433347094175,
#   'val_acc': 0.13459420335462757,
#   'best_val_acc': 0.13459420335462757,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 19,
#   'cross_entropy_loss': 10.514496731289254,
#   'val_loss': 10.907533759953555,
#   'val_acc': 0.13459420335462757,
#   'best_val_acc': 0.13459420335462757,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf},
#  {'epoch': 20,
#   'cross_entropy_loss': 10.51586723488447,
#   'val_loss': 10.907533759953555,
#   'val_acc': 0.13459420335462757,
#   'best_val_acc': 0.13459420335462757,
#   'best_test_acc': 0.0,
#   'best_test_loss': inf}]

# %%
import glob
import matplotlib.pyplot as plt

def load_jsonl(path):
    rows = []
    with open(path, "r") as f:
        for line in f:
            rows.append(json.loads(line))
    return rows


def load_run(name):
    path = pathlib.Path(root_out_dir) / name / f"eval_{name}.jsonl"
    return load_jsonl(path)


def plot_metric(names, metric, title):
    plt.figure(figsize=(8, 5))
    for name in names:
        rows = load_run(name)
        xs = [r["epoch"] for r in rows]
        ys = [r[metric] for r in rows]
        plt.plot(xs, ys, label=name)
    plt.xlabel("Epoch")
    plt.ylabel(metric)
    plt.title(title)
    plt.legend(fontsize=8)
    plt.grid(True, alpha=0.3)
    plt.show()


names = [cfg["name"] for cfg in EXPERIMENTS]

plot_metric(names, "cross_entropy_loss", "Training Cross-Entropy (exp_4)")
plot_metric(names, "val_loss", "Validation Loss (exp_4)")
plot_metric(names, "val_acc", "Validation Accuracy (exp_4)")
